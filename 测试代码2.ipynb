# %%
import re
import os
import json
import datetime
import time
import random
from loguru import logger as 日志
import shutil

# %%
项目_根路径 = '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project'

# %%
项目_中文目录映射= {'示例代码': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project', '', ''], '处理后': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/处理后', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send', '', ''], '原文件': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/原文件', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send', '', ''], '6章合并': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/6章合并', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send', '', ''], '翻译工具': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/翻译工具', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project', '', '']}

# %%
import os

# 示例的中文-英文目录映射
chinese_to_english = {
    '示例代码': 'Example_Code',
    '处理后': 'Processed',
    '原文件': 'Original_Files',
    '6章合并': 'Chapter_6_Merged',
    '翻译工具': 'Translation_Tools'
}

# 项目中的中文目录映射
project_chinese_dirs = {
    '示例代码': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project'],
    '处理后': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/处理后', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send'],
    '原文件': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/原文件', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send'],
    '6章合并': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/6章合并', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send'],
    '翻译工具': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/翻译工具', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project']
}

# %%
for chinese_dir, paths in project_chinese_dirs.items():
    original_path = paths[0]
    parent_path = paths[1]
    
    # 获取对应的英文目录名
    english_dir_name = chinese_to_english[chinese_dir]
    # print(original_path)
    # print(parent_path)
    # print(english_dir_name)
    # print("_________")
    # 
    # 检查父目录是否包含中文，并确定英文父目录的路径
    parent_dirs = parent_path.split(os.sep)
    print(parent_path)
    print(parent_dirs)
    print("_________")
    
    new_parent_path = ""
    for part in parent_dirs:
        if part in chinese_to_english:
            new_parent_path = os.path.join(new_parent_path, chinese_to_english[part])
        else:
            new_parent_path = os.path.join(new_parent_path, part)
            
    # 构造新的英文目录路径
    english_dir_path = os.path.join(new_parent_path, english_dir_name)
    
    print(english_dir_path)
    
    print("_________")
# Out:
# /Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project
# ['', 'Users', 'yangxinyi', 'Library', 'CloudStorage', 'OneDrive-个人', '100_code', 'Test_Translate_Project']
# _________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 23
#      21         new_parent_path = os.path.join(new_parent_path, chinese_to_english[part])
#      22     else:
# ---> 23         new_parent_path = os.path.join(new_parent_path, part)
#      25 # 构造新的英文目录路径
#      26 english_dir_path = os.path.join(new_parent_path, english_dir_name)
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1187, in _pydevd_bundle.pydevd_cython_darwin_311_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:627, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1103, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1061, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_plugin.py:169, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     167     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     168     if frame:
# --> 169         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     170         return True
#     171 return False
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1182         from_this_thread.append(frame_id)
#    1184 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1185     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1200, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1197             self._call_mpl_hook()
#    1199         self.process_internal_commands()
# -> 1200         time.sleep(0.01)
#    1202 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1204 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
t = "/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project"

# %%
t.split(os.sep)
# Out:
# ['',
#  'Users',
#  'yangxinyi',
#  'Library',
#  'CloudStorage',
#  'OneDrive-个人',
#  '100_code',
#  'Test_Translate_Project']

# %%
new_parent_path = ""

# %%
os.path.join(new_parent_path, "Example_Code")
# Out:
# 'Example_Code'

# %%
import os

# 示例的中文-英文目录映射
chinese_to_english = {
    '示例代码': 'Example_Code',
    '处理后': 'Processed',
    '原文件': 'Original_Files',
    '6章合并': 'Chapter_6_Merged',
    '翻译工具': 'Translation_Tools'
}

# 项目中的中文目录映射
project_chinese_dirs = {
    '示例代码': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project'],
    '处理后': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/处理后', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send'],
    '原文件': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/原文件', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send'],
    '6章合并': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send/6章合并', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/示例代码/novel_send'],
    '翻译工具': ['/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project/翻译工具', '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project']
}

# 项目的根目录
root_directory = "/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project"

def create_english_directories(chinese_to_english, project_chinese_dirs, root_directory):
    for chinese_dir, paths in project_chinese_dirs.items():
        original_path = paths[0]
        parent_path = paths[1]

        # 如果是根目录中的中文目录，跳过翻译
        if parent_path == root_directory:
            continue
        
        # 获取对应的英文目录名
        english_dir_name = chinese_to_english[chinese_dir]
        
        # 检查父目录是否包含中文，并确定英文父目录的路径
        parent_dirs = parent_path.split(os.sep)
        new_parent_path = root_directory  # 从根目录开始构建路径
        
        for part in parent_dirs[len(root_directory.split(os.sep)):]:
            if part in chinese_to_english:
                new_parent_path = os.path.join(new_parent_path, chinese_to_english[part])
            else:
                new_parent_path = os.path.join(new_parent_path, part)
        
        # 构造新的英文目录路径
        english_dir_path = os.path.join(new_parent_path, english_dir_name)
        
        # 创建对应的英文目录
        if not os.path.exists():
            os.makedirs(english_dir_path)
            print(f"Created directory: {english_dir_path}")
        else:
            print(f"Directory already exists: {english_dir_path}")

# 执行目录创建
create_english_directories(chinese_to_english, project_chinese_dirs, root_directory)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 57
#      54             print(f"Directory already exists: {english_dir_path}")
#      56 # 执行目录创建
# ---> 57 create_english_directories(chinese_to_english, project_chinese_dirs, root_directory)
#
# Cell In[27], line 54, in create_english_directories(chinese_to_english, project_chinese_dirs, root_directory)
#      52     print(f"Created directory: {english_dir_path}")
#      53 else:
# ---> 54     print(f"Directory already exists: {english_dir_path}")
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1187, in _pydevd_bundle.pydevd_cython_darwin_311_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:627, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1103, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython_darwin_311_64.pyx:1061, in _pydevd_bundle.pydevd_cython_darwin_311_64.PyDBFrame.trace_dispatch()
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_plugin.py:169, in stop(plugin, pydb, frame, event, args, stop_info, arg, step_cmd)
#     167     frame = suspend_jupyter(main_debugger, thread, frame, step_cmd)
#     168     if frame:
# --> 169         main_debugger.do_wait_suspend(thread, frame, event, arg)
#     170         return True
#     171 return False
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1182         from_this_thread.append(frame_id)
#    1184 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1185     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File /Applications/PyCharm.app/Contents/plugins/python/helpers/pydev/pydevd.py:1200, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1197             self._call_mpl_hook()
#    1199         self.process_internal_commands()
# -> 1200         time.sleep(0.01)
#    1202 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1204 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
# 获取当前文件的绝对路径
current_file_path = os.path.abspath("/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Code_Chinese_to_Enghlish/中文变量翻译.py")
# 获取当前文件所在的目录
current_directory = os.path.dirname(current_file_path)
# 改变工作目录到当前文件所在的目录
os.chdir(current_directory)
日志.info("工作目录已改变为: {}", os.getcwd())
# Out:
# 2024-08-11 19:02:47.952 | INFO     | __main__:<module>:7 - 工作目录已改变为: /Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Code_Chinese_to_Enghlish

# %%
from 项目翻译 import *

# %%
项目_根路径 = '/Users/yangxinyi/Downloads/Test_Translate_Project'
收集_目录列表, 收集_文件列表 = 遍历目录和文件列表(项目_根路径)

# %%
收集_目录列表
# Out:
# ['/Users/yangxinyi/Downloads/Test_Translate_Project',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/unnamed_folder',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/example',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/example/novel_send',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/example/novel_send/chapter_6_merged',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/example/novel_send/original_file',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/example/novel_send/processed',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/text_code',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/text_code/一个文件夹',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/text_code/一个文件夹/又一个文件夹',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/未命名文件夹',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/示例代码',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/示例代码/novel_send',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/示例代码/novel_send/处理后',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/示例代码/novel_send/原文件',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/示例代码/novel_send/6章合并',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/翻译工具',
#  '/Users/yangxinyi/Downloads/Test_Translate_Project/translation_tool']

# %%
收集_相对目录列表 = [元素.replace(项目_根路径, "") for 元素 in 收集_目录列表]

# %%
收集_相对目录列表
# Out:
# ['',
#  '/unnamed_folder',
#  '/example',
#  '/example/novel_send',
#  '/example/novel_send/chapter_6_merged',
#  '/example/novel_send/original_file',
#  '/example/novel_send/processed',
#  '/text_code',
#  '/text_code/一个文件夹',
#  '/text_code/一个文件夹/又一个文件夹',
#  '/未命名文件夹',
#  '/示例代码',
#  '/示例代码/novel_send',
#  '/示例代码/novel_send/处理后',
#  '/示例代码/novel_send/原文件',
#  '/示例代码/novel_send/6章合并',
#  '/翻译工具',
#  '/translation_tool']

# %%
项目_目录映射 = {}
项目_中文目录映射 = {}
for 完整路径 in 收集_相对目录列表:
    if 完整路径:
        上层目录名称, 文件夹名称 = 完整路径.rsplit("/", maxsplit=1)
        项目_目录映射[文件夹名称] = ["", 完整路径, "", 上层目录名称, "", 0]
        if 判断中文变量(文件夹名称):  # 过滤带有中文的目录
            项目_中文目录映射[文件夹名称] = ["", 完整路径, "", 上层目录名称, "", 0]
            

合并后变量 = 查询并合并变量(项目_中文目录映射.keys())
项目_中文目录映射
# Out:
# 2024-08-11 19:14:49.632 | DEBUG    | 项目翻译:查询并合并变量:337 - 未检测到重复项
# {'一个文件夹': ['a_folder', '/text_code/一个文件夹', '', '/text_code', '', 0],
#  '又一个文件夹': ['another_folder',
#   '/text_code/一个文件夹/又一个文件夹',
#   '',
#   '/text_code/一个文件夹',
#   '',
#   0],
#  '未命名文件夹': ['unnamed_folder', '/未命名文件夹', '', '', '', 0],
#  '示例代码': ['example', '/示例代码', '', '', '', 0],
#  '处理后': ['processed', '/示例代码/novel_send/处理后', '', '/示例代码/novel_send', '', 0],
#  '原文件': ['original_file',
#   '/示例代码/novel_send/原文件',
#   '',
#   '/示例代码/novel_send',
#   '',
#   0],
#  '6章合并': ['chapter_6_merged',
#   '/示例代码/novel_send/6章合并',
#   '',
#   '/示例代码/novel_send',
#   '',
#   0],
#  '翻译工具': ['translation_tool', '/翻译工具', '', '', '', 0]}

# %%
项目_中文目录映射
# 0 对应 英文变量
# 1 对应 完整路径
# 2 对应 完整路径 翻译成英文
# 3 对应上层路径
# 4 对应上层路径翻译成英文
# 5 0, 1, 对应上级是否进行过修改, 如果修改则不用保留中文对应文件夹, 如果没有修改过, 则应该保留
# Out:
# {'一个文件夹': ['a_folder', '/text_code/一个文件夹', '', '/text_code', '', 0],
#  '又一个文件夹': ['another_folder',
#   '/text_code/一个文件夹/又一个文件夹',
#   '',
#   '/text_code/一个文件夹',
#   '',
#   0],
#  '未命名文件夹': ['unnamed_folder', '/未命名文件夹', '', '', '', 0],
#  '示例代码': ['example', '/示例代码', '', '', '', 0],
#  '处理后': ['processed', '/示例代码/novel_send/处理后', '', '/示例代码/novel_send', '', 0],
#  '原文件': ['original_file',
#   '/示例代码/novel_send/原文件',
#   '',
#   '/示例代码/novel_send',
#   '',
#   0],
#  '6章合并': ['chapter_6_merged',
#   '/示例代码/novel_send/6章合并',
#   '',
#   '/示例代码/novel_send',
#   '',
#   0],
#  '翻译工具': ['translation_tool', '/翻译工具', '', '', '', 0]}

# %%
for 文件夹名称 in 项目_中文目录映射:
    项目_中文目录映射[文件夹名称][0] = 合并后变量[文件夹名称]
    if not 项目_中文目录映射[文件夹名称][5]:  # 这个文件夹还没有被替换过路径, 就是原生路径
        # 直接创建该文件夹, 
        上级英文目录 = 项目_中文目录映射[文件夹名称][3]
        创建目录 = 项目_根路径 + "/" + 上级英文目录 + "/" + 项目_中文目录映射[文件夹名称][0]
        原目录 =  项目_根路径 + "/" + 上级英文目录 + "/" + 文件夹名称
        项目_中文目录映射[文件夹名称][2] = 项目_中文目录映射[文件夹名称][1].replace(文件夹名称, 合并后变量[文件夹名称])
        if not os.path.exists(创建目录):
            shutil.copytree(原目录, 创建目录)
        for 目录 in 项目_中文目录映射:  # 
            if 项目_中文目录映射[目录][1] != 项目_中文目录映射[文件夹名称][1]:
                if 项目_中文目录映射[目录][3].find(项目_中文目录映射[文件夹名称][1]) > -1:
                    # 上层目录修改过, 标记一下
                    项目_中文目录映射[目录][5] = 1
                    项目_中文目录映射[目录][4] = 项目_中文目录映射[目录][3].replace(项目_中文目录映射[文件夹名称][1], 项目_中文目录映射[文件夹名称][2])
        # 将原文件夹中的所有内容复制过来
    else:  # 说明不是第一层文件夹
        # 走到这里说明父路径已经被替换过了, 这不是原生文件夹, 可以直接改名
        上级英文目录 = 项目_中文目录映射[文件夹名称][4]
        创建目录 = 项目_根路径 + 上级英文目录 + "/" + 项目_中文目录映射[文件夹名称][0]
        原目录 =  项目_根路径 + 上级英文目录 + "/" + 文件夹名称
        if not os.path.exists(创建目录):
            os.rename(原目录, 创建目录)
        # else:  # 如果第一层级文件夹本来就是英文, 则到这里它的父文件夹还没变过, 那么需要保留
    
        
        
项目_中文目录映射
# Out:
# {'一个文件夹': ['a_folder',
#   '/text_code/一个文件夹',
#   '/text_code/a_folder',
#   '/text_code',
#   '',
#   0],
#  '又一个文件夹': ['another_folder',
#   '/text_code/一个文件夹/又一个文件夹',
#   '',
#   '/text_code/一个文件夹',
#   '/text_code/a_folder',
#   1],
#  '未命名文件夹': ['unnamed_folder', '/未命名文件夹', '/unnamed_folder', '', '', 0],
#  '示例代码': ['example', '/示例代码', '/example', '', '', 0],
#  '处理后': ['processed',
#   '/示例代码/novel_send/处理后',
#   '',
#   '/示例代码/novel_send',
#   '/example/novel_send',
#   1],
#  '原文件': ['original_file',
#   '/示例代码/novel_send/原文件',
#   '',
#   '/示例代码/novel_send',
#   '/example/novel_send',
#   1],
#  '6章合并': ['chapter_6_merged',
#   '/示例代码/novel_send/6章合并',
#   '',
#   '/示例代码/novel_send',
#   '/example/novel_send',
#   1],
#  '翻译工具': ['translation_tool', '/翻译工具', '/translation_tool', '', '', 0]}

# %% [markdown]
# 首先从父层级一层一个往下面改, 这样可以保证, 每一层级, 当前层级处理完成之后, 当前层级就全是英文了,
# 然后所有文件已经复制了一份到英文文件夹当中.
# 后面就处理这个子文件夹就可以了,
#
# 子文件夹再判断其中的目录名是否存在中文, 如果存在中文的, 则在同一层级, 创建一个英文目录, 然后将中文目录中的所有内容复制过去.
#
# 然后如果这个上一层级已经有过复制了, 那么就将中文目录直接删除掉.
# 如果这个上层目录没有过复制记录, 那么就保留中文的目录.

# %%
哈哈 = "没错 \
这是可以换行的"
# Out:
#   Cell In[123], line 1
#     哈哈 = "没错 \
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# 示例代码
code_text = '''
kkk = "++++"
测试 = "666"
哈哈 = "没错 \
这是可以换行的"
print(测试)
a = '测试 = "666"'
b = "测试 = '666'"
c = """这是一个多行字符串，
里面包含 哈哈 = 777 变量"""
'''

# %%
# 替换映射
variable_map = {
    'kkk': 'fff', 
    '测试': 'test', 
    '哈哈': "haha"
}

# %%
# 识别所有的字符串部分 (包括单引号和双引号, 以及单行和多行字符串)
string_pattern = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\'|\".*?\"|\'.*?\')'

# 修改为跨行匹配模式
multi_line_string_pattern = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\')'

# %%
re.findall(string_pattern, code_text, flags=re.DOTALL)
# Out:
# ['"++++"',
#  '"666"',
#  '"没错 这是可以换行的"',
#  '\'测试 = "666"\'',
#  '"测试 = \'666\'"',
#  '"""这是一个多行字符串，\n里面包含 哈哈 = 777 变量"""']

# %%
# 用于替换的回调函数
def replacer(match):
    matched_text = match.group(0)
    print(matched_text)
    print("------")
    if matched_text.startswith(('"', "'")):
        # 如果是字符串（包括多行字符串），直接返回不做替换
        return matched_text
    else:
        # 如果是变量名，根据映射进行替换
        return variable_map.get(matched_text, matched_text)

# %%
# 构造变量名的正则表达式 (注意这里使用了 \b 进行词边界匹配)
variable_pattern = r'\b(' + '|'.join(re.escape(var) for var in variable_map.keys()) + r')\b'

# %%
variable_pattern
# Out:
# '\\b(kkk|测试|哈哈)\\b'

# %%
# 合并字符串匹配模式和变量匹配模式
combined_pattern = multi_line_string_pattern + r'|' + string_pattern + r'|' + variable_pattern
combined_pattern
# Out:
# '(\\"\\"\\".*?\\"\\"\\"|\\\'\\\'\\\'.*?\\\'\\\'\\\')|(\\"\\"\\".*?\\"\\"\\"|\\\'\\\'\\\'.*?\\\'\\\'\\\'|\\".*?\\"|\\\'.*?\\\')|\\b(kkk|测试|哈哈)\\b'

# %%
# 使用 sub 函数进行替换，结合字符串的保护
code_text = re.sub(combined_pattern, replacer, code_text, flags=re.DOTALL)
print(code_text)
# Out:
# kkk
# ------
# "++++"
# ------
# "666"
# ------
# '测试 = "666"'
# ------
# "测试 = '666'"
# ------
# """这是一个多行字符串，
# 里面包含 哈哈 = 777 变量"""
# ------
#
# fff = "++++"
# test = "666"
# print(test)
# a = '测试 = "666"'
# b = "测试 = '666'"
# c = """这是一个多行字符串，
# 里面包含 哈哈 = 777 变量"""

# %%
def replace_variables(code_text, variable_map):
    # 识别所有的字符串部分 (包括单引号和双引号, 以及单行和多行字符串)
    string_pattern = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\'|\".*?\"|\'.*?\')'
    
    # 修改为跨行匹配模式
    multi_line_string_pattern = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\')'
    
    # 用于替换的回调函数
    def replacer(match):
        matched_text = match.group(0)
        if matched_text.startswith(('"', "'")):
            # 如果是字符串（包括多行字符串），直接返回不做替换
            return matched_text
        else:
            # 如果是变量名，根据映射进行替换
            return variable_map.get(matched_text, matched_text)
    
    # 构造变量名的正则表达式 (注意这里使用了 \b 进行词边界匹配)
    variable_pattern = r'\b(' + '|'.join(re.escape(var) for var in variable_map.keys()) + r')\b'
    
    # 合并字符串匹配模式和变量匹配模式
    combined_pattern = multi_line_string_pattern + r'|' + string_pattern + r'|' + variable_pattern
    
    # 使用 sub 函数进行替换，结合字符串的保护
    code_text = re.sub(combined_pattern, replacer, code_text, flags=re.DOTALL)
    
    return code_text

# 示例代码
code_text = '''
测试 = "666"
print(测试)
a = '测试 = "666"'
b = "测试 = '666'"
c = """这是一个多行字符串，里面包含 测试 变量"""
'''

# 替换映射
variable_map = {
    '测试': 'test'
}

# 进行替换
new_code_text = replace_variables(code_text, variable_map)

# 输出结果
print(new_code_text)
# Out:
# test = "666"
# print(test)
# a = '测试 = "666"'
# b = "测试 = '666'"
# c = """这是一个多行字符串，里面包含 测试 变量"""

# %%
import re

# 测试字符串包含中文字符
test_string = '你好世界'

# 使用 \w 进行匹配
matches = re.findall(r'\w', test_string)

# 输出匹配结果
print(matches)  # 输出 ['你', '好', '世', '界']
# Out:
# ['你', '好', '世', '界']

# %%
with open("项目翻译.py", "r") as 文件:
    代码文本 = 文件.read()

# %%
# 匹配注释部分
注释匹配模式 = r'(#.*?)\n'
字符串匹配模式 = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\'|\".*?\"|\'.*?\')'
# 修改为跨行匹配模式
多行字符串匹配模式 = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\')'
变量匹配模式 = r'\b(\w*[\u4e00-\u9fff]+\w*)\b'

# %%
# 合并所有模式
综合匹配模式 = 注释匹配模式 + r'|' + 多行字符串匹配模式 + r'|' + 字符串匹配模式 + r'|' + 变量匹配模式

# %%
re.findall(综合匹配模式, 代码文本, flags=re.DOTALL)
# Out:
# [('', '', '', '日志'),
#  ('', '', '', '翻译工具'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '内置变量'),
#  ('', '', '', '代码工具'),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', '已保存变量_路径'),
#  ('', '', '"已保存变量.json"', ''),
#  ('# 原始代码', '', '', ''),
#  ('', '', '', '代码文本'),
#  ('',
#   '\'\'\'\nimport 张三\nimport 张三, 李四\nimport pandas as 数据处理\nimport re as 正则表达式, os as 文件管理包\nfrom numpy import array\nfrom numpy import ndarray as 数组\nfrom datetime import datetime as 时间, date as 日期\n\nimport re\nimport re, os\nimport pandas as 数据处理\nimport re as 正则表达式, os as 文件管理包\nfrom numpy import 数组\nfrom numpy import ndarray as 数组\nfrom datetime import datetime as 时间, date as 日期\n\n# 获取当前代码文件的绝对路径\n当前_文件_路径 = os.path.abspath(__file__)\n# 获取该路径的目录部分\n当前_文件 = os.path.dirname(当前_文件_路径)\n\n# 将工作目录切换到代码所在目录\nos.chdir(当前_文件)\n\n# 打印当前工作目录（确认更改）\nprint("当前工作目录：", os.getcwd())\n# 思路, 设置几个类呢?\n# 第一个 小说处理类\n# 第二个 邮件发送类\n\nclass 小说处理器_类:\n    def __init__(self, 小说名称, 输入文件_路径, 输出文件_路径):\n        self.小说内容 = None\n        self.章节正则匹配模式 = None\n        self.小说名称 = 小说名称\n        if not os.path.exists(输出文件_路径):\n            os.mkdir(输出文件_路径)\n        self.输入文件_路径 = 输入文件_路径\n        self.输出文件_路径 = 输出文件_路径\n        正则表达式.\n\n    def 读取小说内容(self):\n        # 第一次的时候执行, 后面不执行\n        self.章节正则匹配模式 = r\'(第\\s*(\\d+|[零一二两三四五六七八九十百千万]+)\\s*章\\s*.*)\'\n        with open(self.输入文件_路径, "r", encoding="utf8") as 文件:\n            # 按行模式读取整本小说内容\n            self.小说内容_按行切分 = 文件.readlines()\n\'\'\'',
#   '',
#   ''),
#  ('', '', '', '匹配代码定义变量'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '匹配到变量_列表'),
#  ('', '', '', '一行'),
#  ('', '', '', '代码文本'),
#  ('', '', '"\\n"', ''),
#  ('', '', '', '一行'),
#  ('', '', '', '一行'),
#  ('# 首先判断不是注释内容, 注释不匹配', '', '', ''),
#  ('', '', '', '一行'),
#  ('', '', '"#"', ''),
#  ('# 注释不处理', '', '', ''),
#  ('# 正则表达式匹配使用等号定义的变量 a = b', '', '', ''),
#  ("# var_pattern = re.compile(r'([0-9a-zA-Z_\\u4e00-\\u9fa5]+)\\s*=\\s*')",
#   '',
#   '',
#   ''),
#  ('', '', "'\\s*([0-9a-zA-Z_\\u4e00-\\u9fa5, ]+?)\\s*=\\s*[^\\s=]+'", ''),
#  ('# 返回有可能是一个变量, 也可能是逗号分割的多个变量组成的字符串', '', '', ''),
#  ('# 提取所有变量名', '', '', ''),
#  ('', '', '', '匹配结果_列表'),
#  ('', '', '', '一行'),
#  ('# 对变量列表进行循环, 如果包含逗号, 说明需要进一步处理', '', '', ''),
#  ("# ['c, d_d ']", '', '', ''),
#  ('', '', '', '元素'),
#  ('', '', '', '匹配结果_列表'),
#  ('', '', '","', ''),
#  ('', '', '', '元素'),
#  ("# ['c, d_d ']", '', '', ''),
#  ('', '', '', '变量'),
#  ('', '', '', '元素'),
#  ('', '', '","', ''),
#  ('', '', '', '匹配到变量_列表'),
#  ('', '', '', '变量'),
#  ('', '', '', '匹配到变量_列表'),
#  ('', '', '', '元素'),
#  ('', '', '', '匹配到变量_列表'),
#  ('', '', '', '提取导入变量'),
#  ('', '', '', '代码文本'),
#  ('', '"""提取所有import 变量和 from xxx import xxx"""', '', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一行'),
#  ('', '', '', '代码文本'),
#  ('', '', '"\\n"', ''),
#  ('# 判断这行是不是以import 开头的', '', '', ''),
#  ('', '', '', '一行'),
#  ('', '', '"import "', ''),
#  ('# 如果是以import 开头的, 分成四种情况,', '', '', ''),
#  ('',
#   '"""import 张三\n                import 宋六, 李四\n                import 王五, sunqi as 孙七\n                import pandas as 数据处理\n                import re as 正则表达式, os as 文件管理包"""',
#   '',
#   ''),
#  ('# 凡是有from的一定是有import 的, 需要的是import后面的内容, 前边from ... import 去掉', '', '', ''),
#  ('', '', '', 'import_后面文本'),
#  ('', '', '', '一行'),
#  ('', '', '"import "', ''),
#  ('', '', '', 'import_后面文本_切分'),
#  ('', '', '', 'import_后面文本'),
#  ('', '', '","', ''),
#  ('', '', '', '一个'),
#  ('', '', '', 'import_后面文本_切分'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('# 没有as, 这个需要单独添加到一个队列当中去, 后续判断是否中文', '', '', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一个'),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', '一个'),
#  ('# 有as, 提取后面部分', '', '', ''),
#  ('# 这里我假设有这种 import 通义千问大模型 as 通义, 两个都是中文, 完全有可能', '', '', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('',
#   '"""from numpy import 测试1\n            from numpy import ndarray as 测试1\n            from datetime import 测试3, date as 测试4\n            from datetime import datetime as 测试5, date as 测试6"""',
#   '',
#   ''),
#  ('', '', '', '一行'),
#  ('', '', '"from "', ''),
#  ('# 提取from后面的变量', '', '', ''),
#  ('', '', '', 'import_前面变量'),
#  ('', '', '', '一行'),
#  ('', '', '"import "', ''),
#  ('', '', '"from"', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', 'import_前面变量'),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', 'import_前面变量'),
#  ('# 凡是有from的一定是有import 的, 需要的是import后面的内容, 前边from ... import 去掉', '', '', ''),
#  ('', '', '', 'import_后面文本'),
#  ('', '', '', '一行'),
#  ('', '', '"import "', ''),
#  ('', '', '', 'import_后面文本_切分'),
#  ('', '', '', 'import_后面文本'),
#  ('', '', '","', ''),
#  ('', '', '', '一个'),
#  ('', '', '', 'import_后面文本_切分'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('# 没有as, 直接保存', '', '', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一个'),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', '一个'),
#  ('# 有as, 提取后面部分', '', '', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', '一个'),
#  ('', '', '"as"', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '固定语法匹配'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '变量列表'),
#  ('# def 传入大模型返回JSON(messages: List[Dict[str, str]]) -> Dict[str, str]:',
#   '',
#   '',
#   ''),
#  ('', '', '"def ([0-9a-zA-Z_\\u4e00-\\u9fa5]+?)\\((.*?)\\).*:"', ''),
#  ('', '', '"class ([0-9a-zA-Z_\\u4e00-\\u9fa5]+?).*\\:"', ''),
#  ('# for_pattern = r"for\\s+([0-9a-zA-Z_\\u4e00-\\u9fa5]+)\\s+in"',
#   '',
#   '',
#   ''),
#  ('', '', '"for\\s+([0-9a-zA-Z_\\u4e00-\\u9fa5\\s,]+?)\\s+in"', ''),
#  ('', '', '"with.*?as\\s(.+?):"', ''),
#  ('', '', '', '一行'),
#  ('', '', '', '代码文本'),
#  ('', '', '"\\n"', ''),
#  ('', '', '', '一行'),
#  ('', '', '', '一行'),
#  ('# 去掉注释内容', '', '', ''),
#  ('', '', '', '一行'),
#  ('', '', '"#"', ''),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '一行'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '函数名称'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '函数参数名称'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '函数名称'),
#  ('# def f():', '', '', ''),
#  ('# def 函数(a):  def 函数(a, b):  def 函数(a, b=1):  def 函数(a="ok", b=1):',
#   '',
#   '',
#   ''),
#  ('# def 函数(a: str, b=1):', '', '', ''),
#  ('# def 函数(a="ok", b=1):   def 函数(a : str="ok", b=1):  def 函数(a : str="ok", b :int=1):',
#   '',
#   '',
#   ''),
#  ('# 规律: 不管怎么样, 多个参数之间一定是用逗号分隔的. 一个参数中有可能有 = , 可能有: , 只要等号和冒号前边的内容',
#   '',
#   '',
#   ''),
#  ('', '', '', '函数参数名称'),
#  ('', '', '', '一个'),
#  ('', '', '', '函数参数名称'),
#  ('', '', '","', ''),
#  ('', '', '', '提取变量'),
#  ('', '', '', '一个'),
#  ('', '', '"="', ''),
#  ('', '', '":"', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '提取变量'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '一行'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '类名称'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '类名称'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '一行'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', 'with匹配结果'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '变量列表'),
#  ('', '', '', 'with匹配结果'),
#  ('# for 目录路径, 目录列表, 文件列表 in os.walk(start_directory):', '', '', ''),
#  ('# 这种没匹配上', '', '', ''),
#  ('', '', '', '搜索结果'),
#  ('', '', '', '一行'),
#  ('', '', '', '搜索结果'),
#  ('', '', '', 'for匹配结果'),
#  ('', '', '', '搜索结果'),
#  ('# for后面可能有1个临时变量, 或者多个临时变量 for 目录路径, 目录列表, 文件列表 in os.walk(start_directory):',
#   '',
#   '',
#   ''),
#  ('', '', '', 'for匹配结果'),
#  ('', '', '","', ''),
#  ('', '', '', '提取变量'),
#  ('', '', '', 'for匹配结果'),
#  ('', '', '","', ''),
#  ('', '', '', '变量列表'),
#  ('', '', '', '提取变量'),
#  ('', '', '', '变量列表'),
#  ('', '', '', 'for匹配结果'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '提取中文变量'),
#  ('', '', '', '变量列表'),
#  ('# 过滤掉英文变量, 如果是中英文混合的, 只要其中包含中文变量', '', '', ''),
#  ('', '', '', '中文变量列表'),
#  ('', '', '', '变量'),
#  ('', '', '', '变量'),
#  ('', '', '', '变量列表'),
#  ('', '', "'\\u4e00'", ''),
#  ('', '', "'\\u9fff'", ''),
#  ('', '', '', '变量'),
#  ('', '', '', '中文变量列表'),
#  ('', '', '', '判断中文变量'),
#  ('', '', '', '变量'),
#  ('', '', "'\\u4e00'", ''),
#  ('', '', "'\\u9fff'", ''),
#  ('', '', '', '变量'),
#  ('', '', '', '遍历目录和文件列表'),
#  ('', '', '', '开始目录'),
#  ('', '', "'.'", ''),
#  ('', '', '', '忽略目录'),
#  ('',
#   '"""\n    列出指定路径下的所有目录和文件，忽略指定的目录。\n\n    :param 开始目录: 起始目录，默认为当前目录。\n    :param 忽略目录: 要忽略的目录列表。\n    """',
#   '',
#   ''),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '忽略目录'),
#  ('', '', '', '忽略目录'),
#  ('', '', "'__pycache__'", ''),
#  ('', '', "'.git'", ''),
#  ('', '', "'.idea'", ''),
#  ('# 遍历目录', '', '', ''),
#  ('', '', '', '目录路径'),
#  ('', '', '', '目录列表'),
#  ('', '', '', '文件列表'),
#  ('', '', '', '开始目录'),
#  ('# 修改 目录列表，移除忽略的目录，影响 os.walk 的遍历行为', '', '', ''),
#  ('', '', '', '目录列表'),
#  ('', '', '', '目录列表'),
#  ('', '', '', '忽略目录'),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '目录路径'),
#  ('# 输出当前目录下的所有文件', '', '', ''),
#  ('', '', '', '文件'),
#  ('', '', '', '文件列表'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '目录路径'),
#  ('', '', '', '文件'),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '关联文件判断'),
#  ('', '', '', '项目绝对路径'),
#  ('',
#   '"""函数功能:\n    公共列表, 关联文件_列表 中保存着import的其他文件,\n\n    from 示例代码 import 案例1\n    from 通义千问大模型 import 翻译中文变量\n    import 示例代码.nover_send\n    import 示例代码\n    import 通义千问大模型\n\n    分别会获取变量 示例代码, 案例1, 通义千问大模型, 翻译中文变量\n    然后我需要判断这几个变量, 到底代表一个包, 还是一个py文件.\n\n    可以把整个项目, 遍历所有文件名, 这样就知道了, 是否在当前项目当中.如果在肯定优先当前项目文件.\n    1. 判断改文件名中是否包含中国字\n    2. 如果包含中国字, 再判断该文件是否在当前项目当中, 如果在当前项目当中, 再判断是目录还是py文件.\n    如果是目录, 则批量替换"""',
#   '',
#   ''),
#  ('', '', '', '关联中文文件_列表'),
#  ('', '', '', '提取中文变量'),
#  ('', '', '', '关联文件_列表'),
#  ('', '', '', '日志'),
#  ('', '', '"关联中文文件_列表: {}"', ''),
#  ('', '', '', '关联中文文件_列表'),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '遍历目录和文件列表'),
#  ('', '', '', '项目绝对路径'),
#  ('# 收集_目录列表 收集_文件列表', '', '', ''),
#  ('# 对 关联中文文件_列表 中的进行判断', '', '', ''),
#  ('', '', '', '日志'),
#  ('', '', '"收集_目录列表: {}"', ''),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '日志'),
#  ('', '', '"收集_文件列表: {}"', ''),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '目录名称映射字典'),
#  ('', '', '', '完整目录'),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '目录名称'),
#  ('', '', '', '完整目录'),
#  ('', '', '"/"', ''),
#  ('', '', '', '目录名称映射字典'),
#  ('', '', '', '目录名称'),
#  ('', '', '', '完整目录'),
#  ('', '', '', '文件名称映射字典'),
#  ('', '', '', '完整文件'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '文件名称'),
#  ('', '', '', '完整文件'),
#  ('', '', '"/"', ''),
#  ('', '', '', '文件名称映射字典'),
#  ('', '', '', '文件名称'),
#  ('', '', '', '完整文件'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '关联中文文件_列表'),
#  ('# /Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Code_Chinese_to_Enghlish/示例代码/__init__.py',
#   '',
#   '',
#   ''),
#  ('# 注意这里面提取出的中文变量, 很可能并没有运行.', '', '', ''),
#  ('', '', '', '中文变量'),
#  ('', '', '', '目录名称映射字典'),
#  ('# 目录', '', '', ''),
#  ('# 在同一层级, 创建一个文件夹', '', '', ''),
#  ('', '', '', '目录映射字典'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '翻译文件名'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '翻译英文名称'),
#  ('', '', '', '目录映射字典'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '完整目录'),
#  ('', '', '', '目录名称映射字典'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '上层目录'),
#  ('', '', '', '完整目录'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '日志'),
#  ('', '', '', '上层目录'),
#  ('', '', '', '翻译英文名称'),
#  ('', '', '', '上层目录'),
#  ('', '', '', '翻译英文名称'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '收集_文件列表'),
#  ('# 传到递归函数里面再次进行处理', '', '', ''),
#  ('# todo', '', '', ''),
#  ('', '', '', '读取已保存变量'),
#  ('# 检查文件是否存在', '', '', ''),
#  ('# # 获取当前文件的绝对路径', '', '', ''),
#  ('# current_file_path = os.path.abspath(__file__)', '', '', ''),
#  ('# # 获取当前文件所在的目录', '', '', ''),
#  ('# current_directory = os.path.dirname(current_file_path)', '', '', ''),
#  ('# # 改变工作目录到当前文件所在的目录', '', '', ''),
#  ('# os.chdir(current_directory)', '', '', ''),
#  ('# 日志.info("工作目录已改变为: {}", os.getcwd())', '', '', ''),
#  ('', '', '', '已保存变量_路径'),
#  ('', '', '', '已保存变量_路径'),
#  ('', '', "'w'", ''),
#  ('', '', "'utf-8'", ''),
#  ('', '', '"测试"', ''),
#  ('', '', '"test"', ''),
#  ('', '', '', '已保存变量_路径'),
#  ('', '', "'r'", ''),
#  ('', '', "'utf-8'", ''),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '保存合并后变量'),
#  ('', '', '', '合并后变量'),
#  ('', '"""传入的应该是一个完整的字典, 然后将字典的值保存进来? """', '', ''),
#  ('', '', '', '已保存变量_路径'),
#  ('', '', "'w'", ''),
#  ('', '', "'utf-8'", ''),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '翻转字典_函数'),
#  ('', '', '', '输入字典'),
#  ('# 创建一个反转的字典，键是原来的值，值是原来的键的列表', '', '', ''),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '键'),
#  ('', '', '', '值'),
#  ('', '', '', '输入字典'),
#  ('', '', '', '值'),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '值'),
#  ('', '', '', '键'),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '值'),
#  ('', '', '', '键'),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '字典重复值检测'),
#  ('', '', '', '输入字典'),
#  ('# 找出所有值的列表长度大于1的条目', '', '', ''),
#  ('', '', '', '重复项'),
#  ('', '', '', '键'),
#  ('', '', '', '值'),
#  ('', '', '', '输入字典'),
#  ('', '', '', '值'),
#  ('', '', '', '值'),
#  ('', '', '', '重复项'),
#  ('', '', '', '键'),
#  ('', '', '', '重复项'),
#  ('', '', '', '查询并合并变量'),
#  ('', '', '', '中文变量列表'),
#  ('# 读取已保存变量, 对其中已经保存的变量进行替换', '', '', ''),
#  ('# 现在是获取到了一个集合, 我需要获取已保存变量, 这是一个字典, 然后', '', '', ''),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '读取已保存变量'),
#  ('# 我想要进行代码文件的替换, 需要一个字典, 不需要过滤, 只要保存的是所有的变量就可以了', '', '', ''),
#  ('# 有一个集合和一个字典, 现在需要从集合中提取出所有不在字典的key当中的数据', '', '', ''),
#  ('', '', '', '未保存变量'),
#  ('', '', '', '元素'),
#  ('', '', '', '元素'),
#  ('', '', '', '中文变量列表'),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '元素'),
#  ('# 几个函数下来, 应该会获取到一个完整的变量列表, 然后将这个变量列表传入到', '', '', ''),
#  ('# 考虑未保存变量为空的情况, 不需要连接大模型', '', '', ''),
#  ('', '', '', '未保存变量'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '翻译中文变量'),
#  ('', '', '', '未保存变量'),
#  ('# 发现这里大模型返回的字典有可能存在确实, 部分传入的变量没有翻译回来, 这里添加一个缺失检测功能', '', '', ''),
#  ('# 如何检测呢? 未保存变量是我要查询的变量, 新变量_字典 查询这个key里面不存在的 未保存变量 元素', '', '', ''),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '元素'),
#  ('', '', '', '元素'),
#  ('', '', '', '未保存变量'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '元素'),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '日志'),
#  ('', '', '"查询到缺失变量: {}"', ''),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '缺失变量翻译_字典'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '翻译中文变量'),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '缺失变量翻译_字典'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '已保存变量'),
#  ('# 放在后面的是保留的, 历史变量优先级更高', '', '', ''),
#  ('# 这里遇到 `传入大模型返回JSON`被大模型变成了 `传入大模型返回_json`, 导致翻译缺失key.', '', '', ''),
#  ('# 如何处理呢? 再次检测是否存在缺失, 如果存在缺失则换成单独翻译添加进去.', '', '', ''),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '元素'),
#  ('', '', '', '元素'),
#  ('', '', '', '未保存变量'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '元素'),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '日志'),
#  ('', '', '"第二次查询到缺失变量: {}"', ''),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '缺失变量翻译_字典'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '翻译文件名'),
#  ('', '', '', '缺失变量'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '缺失变量翻译_字典'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '新变量_字典'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '已保存变量'),
#  ('# 防止出现两个中文变量被翻译成同样的中文, 这里要进行重复数据检查.', '', '', ''),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '翻转字典_函数'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '重复项'),
#  ('', '', '', '字典重复值检测'),
#  ('', '', '', '翻转字典'),
#  ('', '', '', '重复项'),
#  ('', '', '', '日志'),
#  ('', '', '"检测到重复项: {}"', ''),
#  ('', '', '', '重复项'),
#  ('', '', '', '去重字典'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '处理重复变量'),
#  ('', '', '', '重复项'),
#  ('', '', '', '日志'),
#  ('', '', '"大模型去重后: {}"', ''),
#  ('', '', '', '去重字典'),
#  ('# 去重后的字典应该, 把这些值覆盖原来的key和value', '', '', ''),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '去重字典'),
#  ('', '', '', '日志'),
#  ('', '', '"未检测到重复项"', ''),
#  ('', '', '', '保存合并后变量'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '函数_替换代码变量'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '变量映射'),
#  ('# 识别所有的字符串部分 (包括单引号和双引号, 以及单行和多行字符串)', '', '', ''),
#  ('', '', '', '字符串匹配模式'),
#  ('', '', '\'(\\"\\"\\".*?\\"\\"\\"|\\\'', ''),
#  ('', '', "'\\'", ''),
#  ('', '', "'\\'", ''),
#  ('', '', '\'|\\".*?\\"|\\\'', ''),
#  ('', '', "')'", ''),
#  ('# 修改为跨行匹配模式', '', '', ''),
#  ('', '', '', '多行字符串匹配模式'),
#  ('', '', '\'(\\"\\"\\".*?\\"\\"\\"|\\\'', ''),
#  ('', '', "'\\'", ''),
#  ('', '', "'\\'", ''),
#  ('', '', "')'", ''),
#  ('# 用于替换的回调函数', '', '', ''),
#  ('', '', '', '替换函数'),
#  ('', '', '', '匹配结果'),
#  ('', '', '', '匹配文本'),
#  ('', '', '', '匹配结果'),
#  ('', '', '', '匹配文本'),
#  ('', '', '\'"\'', ''),
#  ('', '', '"\'"', ''),
#  ('# 如果是字符串（包括多行字符串），直接返回不做替换', '', '', ''),
#  ('', '', '', '匹配文本'),
#  ('# 如果是变量名，根据映射进行替换', '', '', ''),
#  ('', '', '', '变量映射'),
#  ('', '', '', '匹配文本'),
#  ('', '', '', '匹配文本'),
#  ('# 构造变量名的正则表达式 (注意这里使用了 \\b 进行词边界匹配)', '', '', ''),
#  ('', '', '', '变量匹配模式'),
#  ('', '', "'\\b('", ''),
#  ('', '', "'|'", ''),
#  ('', '', '', '中文变量'),
#  ('', '', '', '中文变量'),
#  ('', '', '', '变量映射'),
#  ('', '', "')\\b'", ''),
#  ('# 合并字符串匹配模式和变量匹配模式', '', '', ''),
#  ('', '', '', '综合匹配模式'),
#  ('', '', '', '多行字符串匹配模式'),
#  ('', '', "'|'", ''),
#  ('', '', '', '字符串匹配模式'),
#  ('', '', "'|'", ''),
#  ('', '', '', '变量匹配模式'),
#  ('# 使用 sub 函数进行替换，结合字符串的保护', '', '', ''),
#  ('', '', '', '代码文本'),
#  ('', '', '', '综合匹配模式'),
#  ('', '', '', '替换函数'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '代码文件翻译'),
#  ('', '', '', '代码_绝对路径'),
#  ('', '', '', '代码_绝对路径'),
#  ('', '', '"r"', ''),
#  ('', '', '', '文件'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '文件'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '变量列表1'),
#  ('', '', '', '匹配代码定义变量'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '变量列表2'),
#  ('', '', '', '提取导入变量'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '变量列表3'),
#  ('', '', '', '固定语法匹配'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '变量列表1'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '变量列表2'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '变量列表3'),
#  ('', '', '', '变量列表_集合'),
#  ('', '', '', '变量列表'),
#  ('', '', '', '中文变量列表'),
#  ('', '', '', '提取中文变量'),
#  ('', '', '', '变量列表_集合'),
#  ('', '', '', '日志'),
#  ('', '', '', '中文变量列表'),
#  ('', '', '', '合并后变量_字典'),
#  ('', '', '', '查询并合并变量'),
#  ('', '', '', '中文变量列表'),
#  ('', '', '', '中文变量映射'),
#  ('', '', '', '变量'),
#  ('', '', '', '合并后变量_字典'),
#  ('', '', '', '变量'),
#  ('', '', '', '变量'),
#  ('', '', '', '中文变量列表'),
#  ('# 替换只需要替换 `中文变量列表` 中的就可以了, 需要一个映射关系', '', '', ''),
#  ('', '', '', '代码文本'),
#  ('', '', '', '函数_替换代码变量'),
#  ('', '', '', '代码文本'),
#  ('', '', '', '中文变量映射'),
#  ('# 保存修改后英文代码, 保存在同一个路径, 文件名称, 原来的中文文件名称翻译成一个英文的文件名称', '', '', ''),
#  ('', '', '', '代码所在目录'),
#  ('', '', '', '代码_绝对路径'),
#  ('# 提取文件名部分', '', '', ''),
#  ('', '', '', '文件名'),
#  ('', '', '', '代码_绝对路径'),
#  ('', '', '', '文件名前缀'),
#  ('', '', '', '文件名后缀'),
#  ('', '', '', '文件名'),
#  ('', '', '"."', ''),
#  ('# 这里有可能文件名早就在已保存变量里面已经有了, 就不再需要翻译了.', '', '', ''),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '读取已保存变量'),
#  ('', '', '', '文件名前缀'),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '文件名前缀_翻译字典'),
#  ('', '', '', '通义千问模型'),
#  ('', '', '', '翻译文件名'),
#  ('', '', '', '文件名前缀'),
#  ('', '', '', '文件名前缀_翻译结果'),
#  ('', '', '', '文件名前缀_翻译字典'),
#  ('', '', '', '文件名前缀'),
#  ('# 将翻译的结果也保存到变量中', '', '', ''),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '文件名前缀'),
#  ('', '', '', '文件名前缀_翻译字典'),
#  ('', '', '', '文件名前缀'),
#  ('', '', '', '保存合并后变量'),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '文件名前缀_翻译结果'),
#  ('', '', '', '已保存变量'),
#  ('', '', '', '文件名前缀'),
#  ('', '', '', '英文代码_保存路径'),
#  ('', '', '', '代码所在目录'),
#  ('', '', '"/"', ''),
#  ('', '', '', '文件名前缀_翻译结果'),
#  ('', '', '"."', ''),
#  ('', '', '', '文件名后缀'),
#  ('', '', '', '英文代码_保存路径'),
#  ('', '', '"w"', ''),
#  ('', '', '', '代码文本'),
#  ('', '', '', '创建英文文件夹'),
#  ('', '', '', '项目_根路径'),
#  ('',
#   '"""函数功能:\n    当传输一个项目路径, 则对项目中的中文路径, 创建一个对应的英文路径\n    对于英文路径不变.\n    对于英文路径当中的中文路径, 创建一个对应的英文目录\n    对于中文路径中的英文路径, 复制到对应的英文父路径\n    对于中文路径中的中文路径, 会在对应的英文父路径中生成对应的英文路径"""',
#   '',
#   ''),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '遍历目录和文件列表'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '', '收集_相对目录列表'),
#  ('', '', '', '元素'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '""', ''),
#  ('', '', '', '元素'),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '项目_目录映射'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '完整路径'),
#  ('', '', '', '收集_相对目录列表'),
#  ('', '', '', '完整路径'),
#  ('# 排除根路径', '', '', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '完整路径'),
#  ('', '', '"/"', ''),
#  ('# 0 对应 英文变量', '', '', ''),
#  ('# 1 对应 完整路径', '', '', ''),
#  ('# 2 对应 完整路径 后续翻译成英文', '', '', ''),
#  ('# 3 对应上层路径', '', '', ''),
#  ('# 4 对应上层路径 后续翻译成英文', '', '', ''),
#  ('# 5 0, 1, 对应上级是否进行过修改, 如果修改则不用保留中文对应文件夹, 如果没有修改过, 则应该保留', '', '', ''),
#  ('', '', '', '项目_目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '""', ''),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"修改标识"', ''),
#  ('', '', '', '判断中文变量'),
#  ('', '', '', '文件夹名称'),
#  ('# 过滤带有中文的目录', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '""', ''),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"修改标识"', ''),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '查询并合并变量'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"修改标识"', ''),
#  ('# 这个文件夹还没有被替换过路径, 就是原生路径', '', '', ''),
#  ('# 直接创建该文件夹, 如果没有修改标识, 代表这个目录的上层都是英文的,', '', '', ''),
#  ('', '', '', '英文上层路径'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '创建目录'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '"/"', ''),
#  ('', '', '', '英文上层路径'),
#  ('', '', '"/"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '', '原目录'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '"/"', ''),
#  ('', '', '', '英文上层路径'),
#  ('', '', '"/"', ''),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '创建目录'),
#  ('', '', '', '原目录'),
#  ('', '', '', '创建目录'),
#  ('# todo: 这里可能需要处理, 如果这个文件夹已经存在了又怎么办呢? 例如又一个 工具 还有一个 tools, 那么最终应该将这两个目录合并起来',
#   '',
#   '',
#   ''),
#  ('# 这里要对所有该目录的子目录的 "英文完整路径", "英文上层路径" 进行修改', '', '', ''),
#  ('', '', '', '目录'),
#  ('', '', '', '项目_中文目录映射'),
#  ('#', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('# 如果不是当前项目', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('# 上层目录修改过, 标记一下', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"修改标识"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('# 将原文件夹中的所有内容复制过来', '', '', ''),
#  ('# 说明不是第一层文件夹', '', '', ''),
#  ('# 走到这里说明父路径已经被替换过了, 这不是原生文件夹, 可以直接改名', '', '', ''),
#  ('', '', '', '英文上层路径'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '创建目录'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '', '英文上层路径'),
#  ('', '', '"/"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '', '原目录'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '', '英文上层路径'),
#  ('', '', '"/"', ''),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '合并后变量'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '', '创建目录'),
#  ('', '', '', '原目录'),
#  ('', '', '', '创建目录'),
#  ('# 如果这个文件夹翻译成英文了, 那么它的子文件夹也都应该将上级目录英文数据翻译一下', '', '', ''),
#  ('', '', '', '目录'),
#  ('', '', '', '项目_中文目录映射'),
#  ('#', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('# 如果不是当前项目', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('# 上层目录修改过, 标记一下', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"修改标识"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '目录'),
#  ('', '', '"上层路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '文件夹名称'),
#  ('', '', '"英文完整路径"', ''),
#  ('# else:  # 如果第一层级文件夹本来就是英文, 则到这里它的父文件夹还没变过, 那么需要保留', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', "'__main__'", ''),
#  ('# 项目根目录的绝对路径', '', '', ''),
#  ("# 项目_根路径 = '/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Test_Translate_Project'",
#   '',
#   '',
#   ''),
#  ('', '', '', '项目_根路径'),
#  ('', '', "'/Users/yangxinyi/Downloads/200_临时文件夹/Test_Project_V3'", ''),
#  ("# 项目_根路径 = '/Users/yangxinyi/Downloads/200_临时文件夹/测试文件夹'", '', '', ''),
#  ('# 项目根目录的绝对路径', '', '', ''),
#  ('# 待处理_代码路径 = "/Users/yangxinyi/Library/CloudStorage/OneDrive-个人/100_code/Code_Chinese_to_Enghlish/中文变量翻译.py"',
#   '',
#   '',
#   ''),
#  ('# 代码文件翻译(待处理_代码路径)', '', '', ''),
#  ('# 日志.info(关联文件_列表)', '', '', ''),
#  ('# 日志.info(收集_文件列表)', '', '', ''),
#  ('# 关联文件判断(project_root)', '', '', ''),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '创建英文文件夹'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '', '日志'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '收集_目录列表'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '遍历目录和文件列表'),
#  ('', '', '', '项目_根路径'),
#  ('', '', '', '日志'),
#  ('', '', '', '收集_文件列表'),
#  ('# 过滤包含中文的py文件, 首先应该将将文件名称提取出来.', '', '', ''),
#  ('', '', '', '项目_文件映射'),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', '完整路径'),
#  ('', '', '', '收集_文件列表'),
#  ('', '', '', '上层路径'),
#  ('', '', '', '文件名称'),
#  ('', '', '', '完整路径'),
#  ('', '', '"/"', ''),
#  ('# 当有两个文件名称都是 测试代码.py的时候, 就会导致后面的将前面的覆盖掉', '', '', ''),
#  ('#', '', '', ''),
#  ('', '', '', '项目_文件映射'),
#  ('', '', '', '文件名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '""', ''),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"修改标识"', ''),
#  ('', '', '', '判断中文变量'),
#  ('', '', '', '文件名称'),
#  ('', '', '', '文件名称'),
#  ('', '', '".py"', ''),
#  ('# 过滤带有中文的目录', '', '', ''),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', '文件名称'),
#  ('', '', '"英文变量"', ''),
#  ('', '', '""', ''),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '完整路径'),
#  ('', '', '"上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '上层路径'),
#  ('', '', '"修改标识"', ''),
#  ('', '', '', '日志'),
#  ('', '', '', '项目_中文文件映射'),
#  ('# 不对啊,', '', '', ''),
#  ("# '/Users/yangxinyi/Downloads/Test_Translate_Project/example/novel_send/小说_发送_脚本.py',",
#   '',
#   '',
#   ''),
#  ("# '/Users/yangxinyi/Downloads/Test_Translate_Project/示例代码/novel_send/小说_发送_脚本.py',",
#   '',
#   '',
#   ''),
#  ('# 现在对于某些代码, 已经有过复制了, 对于有复制记录的, 应该翻译复制之后的,', '', '', ''),
#  ('# 对于没有复制记录的, 应该翻译原来的, 所以需要判断是否有过翻译记录', '', '', ''),
#  ('# 1. 提取出 "完整路径" 序列, 如果在这里, 就不处理', '', '', ''),
#  ('# 2. 提取出 "\'英文完整路径\'" 序列, 如果在这里, 就替换', '', '', ''),
#  ('# 3. 如果不在这两个当中, 就是原生的, 创建一个新的英文版本, 原来的保留.', '', '', ''),
#  ('', '', '', '完整路径_列表'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '中文目录'),
#  ('', '', '"完整路径"', ''),
#  ('', '', '', '中文目录'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '英文完整路径_列表'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', '中文目录'),
#  ('', '', '"英文完整路径"', ''),
#  ('', '', '', '中文目录'),
#  ('', '', '', '项目_中文目录映射'),
#  ('', '', '', 'py文件'),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', 'py文件'),
#  ('', '', '"上层路径"', ''),
#  ('', '', '', '完整路径_列表'),
#  ('# 不用处理', '', '', ''),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', 'py文件'),
#  ('', '', '"英文上层路径"', ''),
#  ('', '', '', '英文完整路径_列表'),
#  ('', '', '', '代码文件翻译'),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', 'py文件'),
#  ('', '', '"英文完整路径"', ''),
#  ('# 翻译成英文', '', '', ''),
#  ('# 删除对应的中文', '', '', ''),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', 'py文件'),
#  ('', '', '"完整路径"', ''),
#  ('# 不在两个当中, 应该是翻译, 但是原来的保留.', '', '', ''),
#  ('', '', '', '代码文件翻译'),
#  ('', '', '', '项目_中文文件映射'),
#  ('', '', '', 'py文件'),
#  ('', '', '"完整路径"', ''),
#  ('# 翻译成英文', '', '', ''),
#  ('# 日志.info(完整路径_列表)', '', '', ''),
#  ('# 日志.info(英文完整路径_列表)', '', '', '')]

# %%
def 函数_替换代码变量(代码文本, 变量映射):
    # 识别所有的字符串部分 (包括单引号和双引号, 以及单行和多行字符串)
    字符串匹配模式 = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\'|\".*?\"|\'.*?\')'

    # 修改为跨行匹配模式
    多行字符串匹配模式 = r'(\"\"\".*?\"\"\"|\'\'\'.*?\'\'\')'

    # 用于替换的回调函数
    def 替换函数(匹配结果):
        匹配文本 = 匹配结果.group(0)
        if 匹配文本.startswith(('"', "'")):
            # 如果是字符串（包括多行字符串），直接返回不做替换
            return 匹配文本
        else:
            # 如果是变量名，根据映射进行替换
            return 变量映射.get(匹配文本, 匹配文本)

    # 构造变量名的正则表达式 (注意这里使用了 \b 进行词边界匹配)
    变量匹配模式 = r'\b(' + '|'.join(re.escape(中文变量) for 中文变量 in 变量映射.keys()) + r')\b'

    # 合并字符串匹配模式和变量匹配模式
    综合匹配模式 = 多行字符串匹配模式 + r'|' + 字符串匹配模式 + r'|' + 变量匹配模式

    # 使用 sub 函数进行替换，结合字符串的保护
    代码文本 = re.sub(综合匹配模式, 替换函数, 代码文本, flags=re.DOTALL)

    return 代码文本
# Out:
# 'import json\nimport re\nimport os, shutil\nimport pandas as pd\nfrom loguru import logger as 日志\nfrom 翻译工具 import 通义千问模型\nfrom 内置变量 import *\nfrom 代码工具 import *\n\n关联文件_列表 = []\n已保存变量_路径 = "已保存变量.json"\n\n# 原始代码\n代码文本 = \'\'\'\nimport 张三\nimport 张三, 李四\nimport pandas as 数据处理\nimport re as 正则表达式, os as 文件管理包\nfrom numpy import array\nfrom numpy import ndarray as 数组\nfrom datetime import datetime as 时间, date as 日期\n\nimport re\nimport re, os\nimport pandas as 数据处理\nimport re as 正则表达式, os as 文件管理包\nfrom numpy import 数组\nfrom numpy import ndarray as 数组\nfrom datetime import datetime as 时间, date as 日期\n\n# 获取当前代码文件的绝对路径\n当前_文件_路径 = os.path.abspath(__file__)\n# 获取该路径的目录部分\n当前_文件 = os.path.dirname(当前_文件_路径)\n\n# 将工作目录切换到代码所在目录\nos.chdir(当前_文件)\n\n# 打印当前工作目录（确认更改）\nprint("当前工作目录：", os.getcwd())\n# 思路, 设置几个类呢?\n# 第一个 小说处理类\n# 第二个 邮件发送类\n\nclass 小说处理器_类:\n    def __init__(self, 小说名称, 输入文件_路径, 输出文件_路径):\n        self.小说内容 = None\n        self.章节正则匹配模式 = None\n        self.小说名称 = 小说名称\n        if not os.path.exists(输出文件_路径):\n            os.mkdir(输出文件_路径)\n        self.输入文件_路径 = 输入文件_路径\n        self.输出文件_路径 = 输出文件_路径\n        正则表达式.\n\n    def 读取小说内容(self):\n        # 第一次的时候执行, 后面不执行\n        self.章节正则匹配模式 = r\'(第\\s*(\\d+|[零一二两三四五六七八九十百千万]+)\\s*章\\s*.*)\'\n        with open(self.输入文件_路径, "r", encoding="utf8") as 文件:\n            # 按行模式读取整本小说内容\n            self.小说内容_按行切分 = 文件.readlines()\n\'\'\'\n\ndef 匹配代码定义变量(代码文本):\n    匹配到变量_列表 = []\n    for 一行 in 代码文本.split("\\n"):\n        一行 = 一行.strip()\n        # 首先判断不是注释内容, 注释不匹配\n        if not 一行.startswith("#"):  # 注释不处理\n            # 正则表达式匹配使用等号定义的变量 a = b\n            # var_pattern = re.compile(r\'([0-9a-zA-Z_\\u4e00-\\u9fa5]+)\\s*=\\s*\')\n            var_pattern = re.compile(r\'\\s*([0-9a-zA-Z_\\u4e00-\\u9fa5, ]+?)\\s*=\\s*[^\\s=]+\')\n            # 返回有可能是一个变量, 也可能是逗号分割的多个变量组成的字符串\n            # 提取所有变量名\n            匹配结果_列表 = var_pattern.findall(一行)\n\n            # 对变量列表进行循环, 如果包含逗号, 说明需要进一步处理\n            # [\'c, d_d \']\n            for 元素 in 匹配结果_列表:\n                if "," in 元素:  # [\'c, d_d \']\n                    for 变量 in 元素.split(","):\n                        匹配到变量_列表.append(变量.strip())\n                else:\n                    匹配到变量_列表.append(元素.strip())\n\n    return 匹配到变量_列表\n\n\ndef 提取导入变量(代码文本):\n    """提取所有import 变量和 from xxx import xxx"""\n\n    变量列表 = []\n    for 一行 in 代码文本.split("\\n"):\n        # 判断这行是不是以import 开头的\n        if 一行.startswith("import "):\n            # 如果是以import 开头的, 分成四种情况,\n            """import 张三\n                import 宋六, 李四\n                import 王五, sunqi as 孙七\n                import pandas as 数据处理\n                import re as 正则表达式, os as 文件管理包"""\n            # 凡是有from的一定是有import 的, 需要的是import后面的内容, 前边from ... import 去掉\n            import_后面文本 = 一行.split("import ")[-1]\n            import_后面文本_切分 = import_后面文本.split(",")\n            for 一个 in import_后面文本_切分:\n                if 一个.find("as") < 0:  # 没有as, 这个需要单独添加到一个队列当中去, 后续判断是否中文\n                    变量列表.append(一个.strip())\n                    关联文件_列表.append(一个.strip())\n                else:  # 有as, 提取后面部分\n                    # 这里我假设有这种 import 通义千问大模型 as 通义, 两个都是中文, 完全有可能\n                    变量列表.append(一个.split("as")[0].strip())\n                    变量列表.append(一个.split("as")[-1].strip())\n                    关联文件_列表.append(一个.split("as")[0].strip())\n\n        """from numpy import 测试1\n            from numpy import ndarray as 测试1\n            from datetime import 测试3, date as 测试4\n            from datetime import datetime as 测试5, date as 测试6"""\n        if 一行.startswith("from "):\n            # 提取from后面的变量\n            import_前面变量 = 一行.split("import ")[0].strip("from").strip()\n            变量列表.append(import_前面变量)\n            关联文件_列表.append(import_前面变量)\n\n            # 凡是有from的一定是有import 的, 需要的是import后面的内容, 前边from ... import 去掉\n            import_后面文本 = 一行.split("import ")[-1]\n            import_后面文本_切分 = import_后面文本.split(",")\n            for 一个 in import_后面文本_切分:\n  ...

# %%
import re

def find_chinese_variables(code_text):
    # 正则表达式：匹配包含中文字符的变量名
    pattern = r'\b\w*[\u4e00-\u9fff]+\w*\b'
    
    # 使用 findall 来获取所有匹配的变量名
    chinese_variables = re.findall(pattern, code_text)
    
    return chinese_variables

# 示例代码
code_text = '''
directory_mapping_dict = tongyi_qianwen_model.翻译文件名(chinese_variable)
directory_mapping_dict = tongyi_qianwen_model.翻译文件名Test(chinese_variable)
directory_mapping_dict = tongyi_qianwen_model.翻译文件名_Test_OK(chinese_variable)
directory_mapping_dict = tongyi_qianwen_model.have_a_fun(chinese_variable)

'''



# 查找包含中文的变量名
chinese_variables = find_chinese_variables(内容)

# 输出结果
print(chinese_variables)
# Out:
# ['日志', '翻译工具', '通义千问模型', '内置变量', '代码工具', '关联文件_列表', '已保存变量_路径', '已保存变量', '原始代码', '代码文本', '张三', '张三', '李四', '数据处理', '正则表达式', '文件管理包', '数组', '时间', '日期', '数据处理', '正则表达式', '文件管理包', '数组', '数组', '时间', '日期', '获取当前代码文件的绝对路径', '当前_文件_路径', '获取该路径的目录部分', '当前_文件', '当前_文件_路径', '将工作目录切换到代码所在目录', '当前_文件', '打印当前工作目录', '确认更改', '当前工作目录', '思路', '设置几个类呢', '第一个', '小说处理类', '第二个', '邮件发送类', '小说处理器_类', '小说名称', '输入文件_路径', '输出文件_路径', '小说内容', '章节正则匹配模式', '小说名称', '小说名称', '输出文件_路径', '输出文件_路径', '输入文件_路径', '输入文件_路径', '输出文件_路径', '输出文件_路径', '正则表达式', '读取小说内容', '第一次的时候执行', '后面不执行', '章节正则匹配模式', '第', '零一二两三四五六七八九十百千万', '章', '输入文件_路径', '文件', '按行模式读取整本小说内容', '小说内容_按行切分', '文件', '匹配代码定义变量', '代码文本', '匹配到变量_列表', '一行', '代码文本', '一行', '一行', '首先判断不是注释内容', '注释不匹配', '一行', '注释不处理', '正则表达式匹配使用等号定义的变量', '返回有可能是一个变量', '也可能是逗号分割的多个变量组成的字符串', '提取所有变量名', '匹配结果_列表', '一行', '对变量列表进行循环', '如果包含逗号', '说明需要进一步处理', '元素', '匹配结果_列表', '元素', '变量', '元素', '匹配到变量_列表', '变量', '匹配到变量_列表', '元素', '匹配到变量_列表', '提取导入变量', '代码文本', '提取所有import', '变量和', '变量列表', '一行', '代码文本', '判断这行是不是以import', '开头的', '一行', '如果是以import', '开头的', '分成四种情况', '张三', '宋六', '李四', '王五', '孙七', '数据处理', '正则表达式', '文件管理包', '凡是有from的一定是有import', '的', '需要的是import后面的内容', '前边from', '去掉', 'import_后面文本', '一行', 'import_后面文本_切分', 'import_后面文本', '一个', 'import_后面文本_切分', '一个', '没有as', '这个需要单独添加到一个队列当中去', '后续判断是否中文', '变量列表', '一个', '关联文件_列表', '一个', '有as', '提取后面部分', '这里我假设有这种', '通义千问大模型', '通义', '两个都是中文', '完全有可能', '变量列表', '一个', '变量列表', '一个', '关联文件_列表', '一个', '测试1', '测试1', '测试3', '测试4', '测试5', '测试6', '一行', '提取from后面的变量', 'import_前面变量', '一行', '变量列表', 'import_前面变量', '关联文件_列表', 'import_前面变量', '凡是有from的一定是有import', '的', '需要的是import后面的内容', '前边from', '去掉', 'import_后面文本', '一行', 'import_后面文本_切分', 'import_后面文本', '一个', 'import_后面文本_切分', '一个', '没有as', '直接保存', '变量列表', '一个', '关联文件_列表', '一个', '有as', '提取后面部分', '变量列表', '一个', '变量列表', '一个', '关联文件_列表', '一个', '变量列表', '固定语法匹配', '代码文本', '变量列表', '传入大模型返回JSON', '一行', '代码文本', '一行', '一行', '去掉注释内容', '一行', '搜索结果', '一行', '搜索结果', '函数名称', '搜索结果', '函数参数名称', '搜索结果', '变量列表', '函数名称', '函数', '函数', '函数', '函数', '函数', '函数', '函数', '函数', '规律', '不管怎么样', '多个参数之间一定是用逗号分隔的', '一个参数中有可能有', '可能有', '只要等号和冒号前边的内容', '函数参数名称', '一个', '函数参数名称', '提取变量', '一个', '变量列表', '提取变量', '搜索结果', '一行', '搜索结果', '类名称', '搜索结果', '变量列表', '类名称', '搜索结果', '一行', '搜索结果', 'with匹配结果', '搜索结果', '变量列表', 'with匹配结果', '目录路径', '目录列表', '文件列表', '这种没匹配上', '搜索结果', '一行', '搜索结果', 'for匹配结果', '搜索结果', 'for后面可能有1个临时变量', '或者多个临时变量', '目录路径', '目录列表', '文件列表', 'for匹配结果', '提取变量', 'for匹配结果', '变量列表', '提取变量', '变量列表', 'for匹配结果', '变量列表', '提取中文变量', '变量列表', '过滤掉英文变量', '如果是中英文混合的', '只要其中包含中文变量', '中文变量列表', '变量', '变量', '变量列表', '变量', '中文变量列表', '判断中文变量', '变量', '变量', '遍历目录和文件列表', '开始目录', '忽略目录', '列出指定路径下的所有目录和文件', '忽略指定的目录', '开始目录', '起始目录', '默认为当前目录', '忽略目录', '要忽略的目录列表', '收集_目录列表', '收集_文件列表', '忽略目录', '忽略目录', '遍历目录', '目录路径', '目录列表', '文件列表', '开始目录', '修改', '目录列表', '移除忽略的目录', '影响', '的遍历行为', '目录列表', '目录列表', '忽略目录', '收集_目录列表', '目录路径', '输出当前目录下的所有文件', '文件', '文件列表', '收集_文件列表', '目录路径', '文件', '收集_目录列表', '收集_文件列表', '关联文件判断', '项目绝对路径', '函数功能', '公共列表', '关联文件_列表', '中保存着import的其他文件', '示例代码', '案例1', '通义千问大模型', '翻译中文变量', '示例代码', '示例代码', '通义千问大模型', '分别会获取变量', '示例代码', '案例1', '通义千问大模型', '翻译中文变量', '然后我需要判断这几个变量', '到底代表一个包', '还是一个py文件', '可以把整个项目', '遍历所有文件名', '这样就知道了', '是否在当前项目当中', '如果在肯定优先当前项目文件', '判断改文件名中是否包含中国字', '如果包含中国字', '再判断该文件是否在当前项目当中', '如果在当前项目当中', '再判断是目录还是py文件', '如果是目录', '则批量替换', '关联中文文件_列表', '提取中文变量', '关联文件_列表', '日志', '关联中文文件_列表', '关联中文文件_列表', '收集_目录列表', '收集_文件列表', '遍历目录和文件列表', '项目绝对路径', '收集_目录列表', '收集_文件列表', '对', '关联中文文件_列表', '中的进行判断', '日志', '收集_目录列表', '收集_目录列表', '日志', '收集_文件列表', '收集_文件列表', '目录名称映射字典', '完整目录', '收集_目录列表', '目录名称', '完整目录', '目录名称映射字典', '目录名称', '完整目录', '文件名称映射字典', '完整文件', '收集_文件列表', '文件名称', '完整文件', '文件名称映射字典', '文件名称', '完整文件', '中文变量', '关联中文文件_列表', '个人', '示例代码', '注意这里面提取出的中文变量', '很可能并没有运行', '中文变量', '目录名称映射字典', '目录', '在同一层级', '创建一个文件夹', '目录映射字典', '通义千问模型', '翻译文件名', '中文变量', '翻译英文名称', '目录映射字典', '中文变量', '完整目录', '目录名称映射字典', '中文变量', '上层目录', '完整目录', '中文变量', '日志', '上层目录', '翻译英文名称', '上层目录', '翻译英文名称', '中文变量', '收集_文件列表', '传到递归函数里面再次进 ...
