# %%
import ast

# %%
path = "/Users/yangxinyi/Downloads/200_临时文件夹/english_test_project/config.py"
with open(path) as f:
    source_code = f.read()

# %%
tree = ast.parse(source_code, mode='exec')

# %%
print(ast.dump(tree, indent=4))
# Out:
# Module(
#     body=[
#         Import(
#             names=[
#                 alias(name='json')]),
#         Import(
#             names=[
#                 alias(name='logging')]),
#         Import(
#             names=[
#                 alias(name='os')]),
#         Import(
#             names=[
#                 alias(name='pickle')]),
#         ImportFrom(
#             module='common.log',
#             names=[
#                 alias(name='logger')],
#             level=0),
#         Import(
#             names=[
#                 alias(name='pandas', asname='pd')]),
#         ImportFrom(
#             module='translate',
#             names=[
#                 alias(name='factory')],
#             level=0),
#         ImportFrom(
#             module='translate.baidu.baidu_translate',
#             names=[
#                 alias(name='BaiduTranslator')],
#             level=0),
#         Expr(
#             value=Call(
#                 func=Name(id='print', ctx=Load()),
#                 args=[
#                     Name(id='factory', ctx=Load())],
#                 keywords=[])),
#         Assign(
#             targets=[
#                 Name(id='a', ctx=Store())],
#             value=Call(
#                 func=Name(id='BaiduTranslator', ctx=Load()),
#                 args=[],
#                 keywords=[])),
#         Assign(
#             targets=[
#                 Name(id='change_config', ctx=Store())],
#             value=Constant(value=1)),
#         Assign(
#             targets=[
#                 Name(id='change_configs', ctx=Store())],
#             value=Constant(value=2)),
#         Assign(
#             targets=[
#                 Name(id='available_setting', ctx=Store())],
#             value=Dict(
#                 keys=[
#                     Constant(value='open_ai_api_key'),
#                     Constant(value='open_ai_api_base'),
#                     Constant(value='proxy'),
#                     Constant(value='model'),
#                     Constant(value='use_azure_chatgpt'),
#                     Constant(value='azure_deployment_id'),
#                     Constant(value='azure_api_version'),
#                     Constant(value='single_chat_prefix'),
#                     Constant(value='single_chat_reply_prefix'),
#                     Constant(value='single_chat_reply_suffix'),
#                     Constant(value='group_chat_prefix'),
#                     Constant(value='group_chat_reply_prefix'),
#                     Constant(value='group_chat_reply_suffix'),
#                     Constant(value='group_chat_keyword'),
#                     Constant(value='group_at_off'),
#                     Constant(value='group_name_white_list'),
#                     Constant(value='group_name_keyword_white_list'),
#                     Constant(value='group_chat_in_one_session'),
#                     Constant(value='nick_name_black_list'),
#                     Constant(value='group_welcome_msg'),
#                     Constant(value='trigger_by_self'),
#                     Constant(value='text_to_image'),
#                     Constant(value='image_proxy'),
#                     Constant(value='image_create_prefix'),
#                     Constant(value='concurrency_in_session'),
#                     Constant(value='image_create_size'),
#                     Constant(value='group_chat_exit_group'),
#                     Constant(value='expires_in_seconds'),
#                     Constant(value='character_desc'),
#                     Constant(value='conversation_max_tokens'),
#                     Constant(value='rate_limit_chatgpt'),
#                     Constant(value='rate_limit_dalle'),
#                     Constant(value='temperature'),
#                     Constant(value='top_p'),
#                     Constant(value='frequency_penalty'),
#                     Constant(value='presence_penalty'),
#                     Constant(value='request_timeout'),
#                     Constant(value='timeout'),
#                     Constant(value='baidu_wenxin_model'),
#                     Constant(value='baidu_wenxin_api_key'),
#                     Constant(value='baidu_wenxin_secret_key'),
#                     Constant(value='xunfei_app_id'),
#                     Constant(value='xunfei_api_key'),
#                     Constant(value='xunfei_api_secret'),
#                     Constant(value='claude_api_cookie'),
#                     Constant(value='claude_uuid'),
#                     Constant(value='qwen_access_key_id'),
#                     Constant(value='qwen_access_key_secret'),
#                     Constant(value='qwen_agent_key'),
#                     Constant(value='qwen_app_id'),
#                     Constant(value='qwen_node_id'),
#                     Constant(value='gemini_api_key'),
#                     Constant(value='wework_smart'),
#                     Constant(value='speech_recognition'),
#                     Constant(value='group_speech_recognition'),
#                     Constant(value='voice_reply_voice'),
#                     Constant(value='always_reply_voice'),
#                     Constant(value='voice_to_text'),
#                     Constant(value='text_to_voice'),
#                     Constant(value='text_to_voice_model'),
#                     Constant(value='tts_voice_id'),
#                     Constant(value='baidu_app_id'),
#                     Constant(value='baidu_api_key'),
#                     Constant(value='baidu_secret_key'),
#                     Constant(value='baidu_dev_pid'),
#                     Constant(value='azure_voice_api_key'),
#                     Constant(value='azure_voice_region'),
#                     Constant(value='xi_api_key'),
#                     Constant(value='xi_voice_id'),
#                     Constant(value='chat_time_module'),
#                     Constant(value='chat_start_time'),
#                     Constant(value='chat_stop_time'),
#                     Constant(value='translate'),
#                     Constant(value='baidu_translate_app_id'),
#                     Constant(value='baidu_translate_app_key'),
#                     Constant(value='hot_reload'),
#                     Constant(value='wechaty_puppet_service_token'),
#                     Constant(value='wechatmp_token'),
#                     Constant(value='wechatmp_port'),
#                     Constant(value='wechatmp_app_id'),
#                     Constant(value='wechatmp_app_secret'),
#                     Constant(value='wechatmp_aes_key'),
#                     Constant(value='wechatcom_corp_id'),
#                     Constant(value='wechatcomapp_token'),
#                     Constant(value='wechatcomapp_port'),
#                     Constant(value='wechatcomapp_secret'),
#                     Constant(value='wechatcomapp_agent_id'),
#                     Constant(value='wechatcomapp_aes_key'),
#                     Constant(value='feishu_port'),
#                     Constant(value='feishu_app_id'),
#                     Constant(value='feishu_app_secret'),
#                     Constant(value='feishu_token'),
#                     Constant(value='feishu_bot_name'),
#                     Constant(value='dingtalk_client_id'),
#                     Constant(value='dingtalk_client_secret'),
#                     Constant(value='clear_memory_commands'),
#                     Constant(value='channel_type'),
#                     Constant(value='subscribe_msg'),
#                     Constant(value='debug'),
#                     Constant(value='appdata_dir'),
#                     Constant(value='plugin_trigger_prefix'),
#                     Constant(value='use_global_plugin_config'),
#                     Constant(value='max_media_send_count'),
#                     Constant(value='media_send_interval'),
#                     Constant(value='use_linkai'),
#                     Constant(value='linkai_api_key'),
#                     Constant(value='linkai_app_code'),
#                     Constant(value='linkai_api_base')],
#                 values=[
#                     Constant(value=''),
#                     Constant(value='https://api.openai.com/v1'),
#                     Constant(value=''),
#                     Constant(value='gpt-3.5-turbo'),
#                     Constant(value=False),
#                     Constant(value=''),
#                     Constant(value=''),
#                     List(
#                         elts=[
#                             Constant(value='bot'),
#                             Constant(value='@bot')],
#                         ctx=Load()),
#                     Constant(value='[bot] '),
#                     Constant(value=''),
#                     List(
#                         elts=[
#                             Constant(value='@bot')],
#                         ctx=Load()),
#                     Constant(value=''),
#                     Constant(value=''),
#                     List(elts=[], ctx=Load()),
#                     Constant(value=False),
#                     List(
#                         elts=[
#                             Constant(value='ChatGPT测试群'),
#                             Constant(value='ChatGPT测试群2')],
#                         ctx=Load()),
#                     List(elts=[], ctx=Load()),
#                     List(
#                         elts=[
#                             Constant(value='ChatGPT测试群')],
#                         ctx=Load()),
#                     List(elts=[], ctx=Load()),
#                     Constant(value=''),
#                     Constant(value=False),
#                     Constant(value='dall-e-2'),
#                     Constant(value=True),
#                     List(
#                         elts=[
#                             Constant(value='画'),
#                             Constant(value='看'),
#                             Constant(value='找')],
#                         ctx=Load()),
#                     Constant(value=1),
#                     Constant(value='256x256'),
#                     Constant(value=False),
#                     Constant(value=3600),
#                     Constant(value='你是ChatGPT, 一个由OpenAI训练的大型语言模型, 你旨在回答并解决人们的任何问题，并且可以使用多种语言与人交流。'),
#                     Constant(value=1000),
#                     Constant(value=20),
#                     Constant(value=50),
#                     Constant(value=0.9),
#                     Constant(value=1),
#                     Constant(value=0),
#                     Constant(value=0),
#                     Constant(value=180),
#                     Constant(value=120),
#                     Constant(value='eb-instant'),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=True),
#                     Constant(value=True),
#                     Constant(value=False),
#                     Constant(value=False),
#                     Constant(value=False),
#                     Constant(value='openai'),
#                     Constant(value='openai'),
#                     Constant(value='tts-1'),
#                     Constant(value='alloy'),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value='1536'),
#                     Constant(value=''),
#                     Constant(value='japaneast'),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=False),
#                     Constant(value='00:00'),
#                     Constant(value='24:00'),
#                     Constant(value='baidu'),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=False),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=8080),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=9898),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=80),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value=''),
#                     List(
#                         elts=[
#                             Constant(value='#清除记忆')],
#                         ctx=Load()),
#                     Constant(value='wx'),
#                     Constant(value=''),
#                     Constant(value=False),
#                     Constant(value=''),
#                     Constant(value='$'),
#                     Constant(value=False),
#                     Constant(value=3),
#                     Constant(value=1),
#                     Constant(value=False),
#                     Constant(value=''),
#                     Constant(value=''),
#                     Constant(value='https://api.link-ai.chat')])),
#         ClassDef(
#             name='Config',
#             bases=[
#                 Name(id='dict', ctx=Load())],
#             keywords=[],
#             body=[
#                 FunctionDef(
#                     name='__init__',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self'),
#                             arg(arg='d')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[
#                             Constant(value=None)]),
#                     body=[
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Call(
#                                         func=Name(id='super', ctx=Load()),
#                                         args=[],
#                                         keywords=[]),
#                                     attr='__init__',
#                                     ctx=Load()),
#                                 args=[],
#                                 keywords=[])),
#                         If(
#                             test=Compare(
#                                 left=Name(id='d', ctx=Load()),
#                                 ops=[
#                                     Is()],
#                                 comparators=[
#                                     Constant(value=None)]),
#                             body=[
#                                 Assign(
#                                     targets=[
#                                         Name(id='d', ctx=Store())],
#                                     value=Dict(keys=[], values=[]))],
#                             orelse=[]),
#                         For(
#                             target=Tuple(
#                                 elts=[
#                                     Name(id='k', ctx=Store()),
#                                     Name(id='v', ctx=Store())],
#                                 ctx=Store()),
#                             iter=Call(
#                                 func=Attribute(
#                                     value=Name(id='d', ctx=Load()),
#                                     attr='items',
#                                     ctx=Load()),
#                                 args=[],
#                                 keywords=[]),
#                             body=[
#                                 Assign(
#                                     targets=[
#                                         Subscript(
#                                             value=Name(id='self', ctx=Load()),
#                                             slice=Name(id='k', ctx=Load()),
#                                             ctx=Store())],
#                                     value=Name(id='v', ctx=Load()))],
#                             orelse=[]),
#                         Assign(
#                             targets=[
#                                 Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='user_datas',
#                                     ctx=Store())],
#                             value=Dict(keys=[], values=[]))],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='__getitem__',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self'),
#                             arg(arg='key')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         If(
#                             test=Compare(
#                                 left=Name(id='key', ctx=Load()),
#                                 ops=[
#                                     NotIn()],
#                                 comparators=[
#                                     Name(id='available_setting', ctx=Load())]),
#                             body=[
#                                 Raise(
#                                     exc=Call(
#                                         func=Name(id='Exception', ctx=Load()),
#                                         args=[
#                                             Call(
#                                                 func=Attribute(
#                                                     value=Constant(value='key {} not in available_setting'),
#                                                     attr='format',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Name(id='key', ctx=Load())],
#                                                 keywords=[])],
#                                         keywords=[]))],
#                             orelse=[]),
#                         Return(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Call(
#                                         func=Name(id='super', ctx=Load()),
#                                         args=[],
#                                         keywords=[]),
#                                     attr='__getitem__',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='key', ctx=Load())],
#                                 keywords=[]))],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='__setitem__',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self'),
#                             arg(arg='key'),
#                             arg(arg='value')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         If(
#                             test=Compare(
#                                 left=Name(id='key', ctx=Load()),
#                                 ops=[
#                                     NotIn()],
#                                 comparators=[
#                                     Name(id='available_setting', ctx=Load())]),
#                             body=[
#                                 Raise(
#                                     exc=Call(
#                                         func=Name(id='Exception', ctx=Load()),
#                                         args=[
#                                             Call(
#                                                 func=Attribute(
#                                                     value=Constant(value='key {} not in available_setting'),
#                                                     attr='format',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Name(id='key', ctx=Load())],
#                                                 keywords=[])],
#                                         keywords=[]))],
#                             orelse=[]),
#                         Return(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Call(
#                                         func=Name(id='super', ctx=Load()),
#                                         args=[],
#                                         keywords=[]),
#                                     attr='__setitem__',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='key', ctx=Load()),
#                                     Name(id='value', ctx=Load())],
#                                 keywords=[]))],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='get',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self'),
#                             arg(arg='key'),
#                             arg(arg='default')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[
#                             Constant(value=None)]),
#                     body=[
#                         Try(
#                             body=[
#                                 Return(
#                                     value=Subscript(
#                                         value=Name(id='self', ctx=Load()),
#                                         slice=Name(id='key', ctx=Load()),
#                                         ctx=Load()))],
#                             handlers=[
#                                 ExceptHandler(
#                                     type=Name(id='KeyError', ctx=Load()),
#                                     name='e',
#                                     body=[
#                                         Return(
#                                             value=Name(id='default', ctx=Load()))]),
#                                 ExceptHandler(
#                                     type=Name(id='Exception', ctx=Load()),
#                                     name='e',
#                                     body=[
#                                         Raise(
#                                             exc=Name(id='e', ctx=Load()))])],
#                             orelse=[],
#                             finalbody=[])],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='get_user_data',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self'),
#                             arg(arg='user')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         If(
#                             test=Compare(
#                                 left=Call(
#                                     func=Attribute(
#                                         value=Attribute(
#                                             value=Name(id='self', ctx=Load()),
#                                             attr='user_datas',
#                                             ctx=Load()),
#                                         attr='get',
#                                         ctx=Load()),
#                                     args=[
#                                         Name(id='user', ctx=Load())],
#                                     keywords=[]),
#                                 ops=[
#                                     Is()],
#                                 comparators=[
#                                     Constant(value=None)]),
#                             body=[
#                                 Assign(
#                                     targets=[
#                                         Subscript(
#                                             value=Attribute(
#                                                 value=Name(id='self', ctx=Load()),
#                                                 attr='user_datas',
#                                                 ctx=Load()),
#                                             slice=Name(id='user', ctx=Load()),
#                                             ctx=Store())],
#                                     value=Dict(keys=[], values=[]))],
#                             orelse=[]),
#                         Return(
#                             value=Subscript(
#                                 value=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='user_datas',
#                                     ctx=Load()),
#                                 slice=Name(id='user', ctx=Load()),
#                                 ctx=Load()))],
#                     decorator_list=[],
#                     returns=Name(id='dict', ctx=Load())),
#                 FunctionDef(
#                     name='load_user_datas',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         Try(
#                             body=[
#                                 With(
#                                     items=[
#                                         withitem(
#                                             context_expr=Call(
#                                                 func=Name(id='open', ctx=Load()),
#                                                 args=[
#                                                     Call(
#                                                         func=Attribute(
#                                                             value=Attribute(
#                                                                 value=Name(id='os', ctx=Load()),
#                                                                 attr='path',
#                                                                 ctx=Load()),
#                                                             attr='join',
#                                                             ctx=Load()),
#                                                         args=[
#                                                             Call(
#                                                                 func=Name(id='get_appdata_dir', ctx=Load()),
#                                                                 args=[],
#                                                                 keywords=[]),
#                                                             Constant(value='user_datas.pkl')],
#                                                         keywords=[]),
#                                                     Constant(value='rb')],
#                                                 keywords=[]),
#                                             optional_vars=Name(id='f', ctx=Store()))],
#                                     body=[
#                                         Assign(
#                                             targets=[
#                                                 Attribute(
#                                                     value=Name(id='self', ctx=Load()),
#                                                     attr='user_datas',
#                                                     ctx=Store())],
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='pickle', ctx=Load()),
#                                                     attr='load',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Name(id='f', ctx=Load())],
#                                                 keywords=[])),
#                                         Expr(
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='logger', ctx=Load()),
#                                                     attr='info',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Constant(value='[Config] User datas loaded.')],
#                                                 keywords=[]))])],
#                             handlers=[
#                                 ExceptHandler(
#                                     type=Name(id='FileNotFoundError', ctx=Load()),
#                                     name='e',
#                                     body=[
#                                         Expr(
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='logger', ctx=Load()),
#                                                     attr='info',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Constant(value='[Config] User datas file not found, ignore.')],
#                                                 keywords=[]))]),
#                                 ExceptHandler(
#                                     type=Name(id='Exception', ctx=Load()),
#                                     name='e',
#                                     body=[
#                                         Expr(
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='logger', ctx=Load()),
#                                                     attr='info',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Call(
#                                                         func=Attribute(
#                                                             value=Constant(value='[Config] User datas error: {}'),
#                                                             attr='format',
#                                                             ctx=Load()),
#                                                         args=[
#                                                             Name(id='e', ctx=Load())],
#                                                         keywords=[])],
#                                                 keywords=[])),
#                                         Assign(
#                                             targets=[
#                                                 Attribute(
#                                                     value=Name(id='self', ctx=Load()),
#                                                     attr='user_datas',
#                                                     ctx=Store())],
#                                             value=Dict(keys=[], values=[]))])],
#                             orelse=[],
#                             finalbody=[])],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='save_user_datas',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         Try(
#                             body=[
#                                 With(
#                                     items=[
#                                         withitem(
#                                             context_expr=Call(
#                                                 func=Name(id='open', ctx=Load()),
#                                                 args=[
#                                                     Call(
#                                                         func=Attribute(
#                                                             value=Attribute(
#                                                                 value=Name(id='os', ctx=Load()),
#                                                                 attr='path',
#                                                                 ctx=Load()),
#                                                             attr='join',
#                                                             ctx=Load()),
#                                                         args=[
#                                                             Call(
#                                                                 func=Name(id='get_appdata_dir', ctx=Load()),
#                                                                 args=[],
#                                                                 keywords=[]),
#                                                             Constant(value='user_datas.pkl')],
#                                                         keywords=[]),
#                                                     Constant(value='wb')],
#                                                 keywords=[]),
#                                             optional_vars=Name(id='f', ctx=Store()))],
#                                     body=[
#                                         Expr(
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='pickle', ctx=Load()),
#                                                     attr='dump',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Attribute(
#                                                         value=Name(id='self', ctx=Load()),
#                                                         attr='user_datas',
#                                                         ctx=Load()),
#                                                     Name(id='f', ctx=Load())],
#                                                 keywords=[])),
#                                         Expr(
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='logger', ctx=Load()),
#                                                     attr='info',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Constant(value='[Config] User datas saved.')],
#                                                 keywords=[]))])],
#                             handlers=[
#                                 ExceptHandler(
#                                     type=Name(id='Exception', ctx=Load()),
#                                     name='e',
#                                     body=[
#                                         Expr(
#                                             value=Call(
#                                                 func=Attribute(
#                                                     value=Name(id='logger', ctx=Load()),
#                                                     attr='info',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Call(
#                                                         func=Attribute(
#                                                             value=Constant(value='[Config] User datas error: {}'),
#                                                             attr='format',
#                                                             ctx=Load()),
#                                                         args=[
#                                                             Name(id='e', ctx=Load())],
#                                                         keywords=[])],
#                                                 keywords=[]))])],
#                             orelse=[],
#                             finalbody=[])],
#                     decorator_list=[])],
#             decorator_list=[]),
#         Assign(
#             targets=[
#                 Name(id='config', ctx=Store())],
#             value=Call(
#                 func=Name(id='Config', ctx=Load()),
#                 args=[],
#                 keywords=[])),
#         FunctionDef(
#             name='load_config',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Global(
#                     names=[
#                         'config']),
#                 Assign(
#                     targets=[
#                         Name(id='config_path', ctx=Store())],
#                     value=Constant(value='./config.json')),
#                 If(
#                     test=UnaryOp(
#                         op=Not(),
#                         operand=Call(
#                             func=Attribute(
#                                 value=Attribute(
#                                     value=Name(id='os', ctx=Load()),
#                                     attr='path',
#                                     ctx=Load()),
#                                 attr='exists',
#                                 ctx=Load()),
#                             args=[
#                                 Name(id='config_path', ctx=Load())],
#                             keywords=[])),
#                     body=[
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='logger', ctx=Load()),
#                                     attr='info',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='配置文件不存在，将使用config-template.json模板')],
#                                 keywords=[])),
#                         Assign(
#                             targets=[
#                                 Name(id='config_path', ctx=Store())],
#                             value=Constant(value='./config-template.json'))],
#                     orelse=[]),
#                 Assign(
#                     targets=[
#                         Name(id='config_str', ctx=Store())],
#                     value=Call(
#                         func=Name(id='read_file', ctx=Load()),
#                         args=[
#                             Name(id='config_path', ctx=Load())],
#                         keywords=[])),
#                 Expr(
#                     value=Call(
#                         func=Attribute(
#                             value=Name(id='logger', ctx=Load()),
#                             attr='debug',
#                             ctx=Load()),
#                         args=[
#                             Call(
#                                 func=Attribute(
#                                     value=Constant(value='[INIT] config str: {}'),
#                                     attr='format',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='config_str', ctx=Load())],
#                                 keywords=[])],
#                         keywords=[])),
#                 Assign(
#                     targets=[
#                         Name(id='config', ctx=Store())],
#                     value=Call(
#                         func=Name(id='Config', ctx=Load()),
#                         args=[
#                             Call(
#                                 func=Attribute(
#                                     value=Name(id='json', ctx=Load()),
#                                     attr='loads',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='config_str', ctx=Load())],
#                                 keywords=[])],
#                         keywords=[])),
#                 For(
#                     target=Tuple(
#                         elts=[
#                             Name(id='name', ctx=Store()),
#                             Name(id='value', ctx=Store())],
#                         ctx=Store()),
#                     iter=Call(
#                         func=Attribute(
#                             value=Attribute(
#                                 value=Name(id='os', ctx=Load()),
#                                 attr='environ',
#                                 ctx=Load()),
#                             attr='items',
#                             ctx=Load()),
#                         args=[],
#                         keywords=[]),
#                     body=[
#                         Assign(
#                             targets=[
#                                 Name(id='name', ctx=Store())],
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='name', ctx=Load()),
#                                     attr='lower',
#                                     ctx=Load()),
#                                 args=[],
#                                 keywords=[])),
#                         If(
#                             test=Compare(
#                                 left=Name(id='name', ctx=Load()),
#                                 ops=[
#                                     In()],
#                                 comparators=[
#                                     Name(id='available_setting', ctx=Load())]),
#                             body=[
#                                 Expr(
#                                     value=Call(
#                                         func=Attribute(
#                                             value=Name(id='logger', ctx=Load()),
#                                             attr='info',
#                                             ctx=Load()),
#                                         args=[
#                                             Call(
#                                                 func=Attribute(
#                                                     value=Constant(value='[INIT] override config by environ args: {}={}'),
#                                                     attr='format',
#                                                     ctx=Load()),
#                                                 args=[
#                                                     Name(id='name', ctx=Load()),
#                                                     Name(id='value', ctx=Load())],
#                                                 keywords=[])],
#                                         keywords=[])),
#                                 Try(
#                                     body=[
#                                         Assign(
#                                             targets=[
#                                                 Subscript(
#                                                     value=Name(id='config', ctx=Load()),
#                                                     slice=Name(id='name', ctx=Load()),
#                                                     ctx=Store())],
#                                             value=Call(
#                                                 func=Name(id='eval', ctx=Load()),
#                                                 args=[
#                                                     Name(id='value', ctx=Load())],
#                                                 keywords=[]))],
#                                     handlers=[
#                                         ExceptHandler(
#                                             body=[
#                                                 If(
#                                                     test=Compare(
#                                                         left=Name(id='value', ctx=Load()),
#                                                         ops=[
#                                                             Eq()],
#                                                         comparators=[
#                                                             Constant(value='false')]),
#                                                     body=[
#                                                         Assign(
#                                                             targets=[
#                                                                 Subscript(
#                                                                     value=Name(id='config', ctx=Load()),
#                                                                     slice=Name(id='name', ctx=Load()),
#                                                                     ctx=Store())],
#                                                             value=Constant(value=False))],
#                                                     orelse=[
#                                                         If(
#                                                             test=Compare(
#                                                                 left=Name(id='value', ctx=Load()),
#                                                                 ops=[
#                                                                     Eq()],
#                                                                 comparators=[
#                                                                     Constant(value='true')]),
#                                                             body=[
#                                                                 Assign(
#                                                                     targets=[
#                                                                         Subscript(
#                                                                             value=Name(id='config', ctx=Load()),
#                                                                             slice=Name(id='name', ctx=Load()),
#                                                                             ctx=Store())],
#                                                                     value=Constant(value=True))],
#                                                             orelse=[
#                                                                 Assign(
#                                                                     targets=[
#                                                                         Subscript(
#                                                                             value=Name(id='config', ctx=Load()),
#                                                                             slice=Name(id='name', ctx=Load()),
#                                                                             ctx=Store())],
#                                                                     value=Name(id='value', ctx=Load()))])])])],
#                                     orelse=[],
#                                     finalbody=[])],
#                             orelse=[])],
#                     orelse=[]),
#                 If(
#                     test=Call(
#                         func=Attribute(
#                             value=Name(id='config', ctx=Load()),
#                             attr='get',
#                             ctx=Load()),
#                         args=[
#                             Constant(value='debug'),
#                             Constant(value=False)],
#                         keywords=[]),
#                     body=[
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='logger', ctx=Load()),
#                                     attr='setLevel',
#                                     ctx=Load()),
#                                 args=[
#                                     Attribute(
#                                         value=Name(id='logging', ctx=Load()),
#                                         attr='DEBUG',
#                                         ctx=Load())],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='logger', ctx=Load()),
#                                     attr='debug',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='[INIT] set log level to DEBUG')],
#                                 keywords=[]))],
#                     orelse=[]),
#                 Expr(
#                     value=Call(
#                         func=Attribute(
#                             value=Name(id='logger', ctx=Load()),
#                             attr='info',
#                             ctx=Load()),
#                         args=[
#                             Call(
#                                 func=Attribute(
#                                     value=Constant(value='[INIT] load config: {}'),
#                                     attr='format',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='config', ctx=Load())],
#                                 keywords=[])],
#                         keywords=[])),
#                 Expr(
#                     value=Call(
#                         func=Attribute(
#                             value=Name(id='config', ctx=Load()),
#                             attr='load_user_datas',
#                             ctx=Load()),
#                         args=[],
#                         keywords=[]))],
#             decorator_list=[]),
#         FunctionDef(
#             name='get_root',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Return(
#                     value=Call(
#                         func=Attribute(
#                             value=Attribute(
#                                 value=Name(id='os', ctx=Load()),
#                                 attr='path',
#                                 ctx=Load()),
#                             attr='dirname',
#                             ctx=Load()),
#                         args=[
#                             Call(
#                                 func=Attribute(
#                                     value=Attribute(
#                                         value=Name(id='os', ctx=Load()),
#                                         attr='path',
#                                         ctx=Load()),
#                                     attr='abspath',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='__file__', ctx=Load())],
#                                 keywords=[])],
#                         keywords=[]))],
#             decorator_list=[]),
#         FunctionDef(
#             name='read_file',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(arg='path')],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 With(
#                     items=[
#                         withitem(
#                             context_expr=Call(
#                                 func=Name(id='open', ctx=Load()),
#                                 args=[
#                                     Name(id='path', ctx=Load())],
#                                 keywords=[
#                                     keyword(
#                                         arg='mode',
#                                         value=Constant(value='r')),
#                                     keyword(
#                                         arg='encoding',
#                                         value=Constant(value='utf-8'))]),
#                             optional_vars=Name(id='f', ctx=Store()))],
#                     body=[
#                         Return(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='f', ctx=Load()),
#                                     attr='read',
#                                     ctx=Load()),
#                                 args=[],
#                                 keywords=[]))])],
#             decorator_list=[]),
#         FunctionDef(
#             name='conf',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Return(
#                     value=Name(id='config', ctx=Load()))],
#             decorator_list=[]),
#         FunctionDef(
#             name='get_appdata_dir',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Assign(
#                     targets=[
#                         Name(id='data_path', ctx=Store())],
#                     value=Call(
#                         func=Attribute(
#                             value=Attribute(
#                                 value=Name(id='os', ctx=Load()),
#                                 attr='path',
#                                 ctx=Load()),
#                             attr='join',
#                             ctx=Load()),
#                         args=[
#                             Call(
#                                 func=Name(id='get_root', ctx=Load()),
#                                 args=[],
#                                 keywords=[]),
#                             Call(
#                                 func=Attribute(
#                                     value=Call(
#                                         func=Name(id='conf', ctx=Load()),
#                                         args=[],
#                                         keywords=[]),
#                                     attr='get',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='appdata_dir'),
#                                     Constant(value='')],
#                                 keywords=[])],
#                         keywords=[])),
#                 If(
#                     test=UnaryOp(
#                         op=Not(),
#                         operand=Call(
#                             func=Attribute(
#                                 value=Attribute(
#                                     value=Name(id='os', ctx=Load()),
#                                     attr='path',
#                                     ctx=Load()),
#                                 attr='exists',
#                                 ctx=Load()),
#                             args=[
#                                 Name(id='data_path', ctx=Load())],
#                             keywords=[])),
#                     body=[
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='logger', ctx=Load()),
#                                     attr='info',
#                                     ctx=Load()),
#                                 args=[
#                                     Call(
#                                         func=Attribute(
#                                             value=Constant(value='[INIT] data path not exists, create it: {}'),
#                                             attr='format',
#                                             ctx=Load()),
#                                         args=[
#                                             Name(id='data_path', ctx=Load())],
#                                         keywords=[])],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='os', ctx=Load()),
#                                     attr='makedirs',
#                                     ctx=Load()),
#                                 args=[
#                                     Name(id='data_path', ctx=Load())],
#                                 keywords=[]))],
#                     orelse=[]),
#                 Return(
#                     value=Name(id='data_path', ctx=Load()))],
#             decorator_list=[]),
#         FunctionDef(
#             name='subscribe_msg',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Assign(
#                     targets=[
#                         Name(id='trigger_prefix', ctx=Store())],
#                     value=Subscript(
#                         value=Call(
#                             func=Attribute(
#                                 value=Call(
#                                     func=Name(id='conf', ctx=Load()),
#                                     args=[],
#                                     keywords=[]),
#                                 attr='get',
#                                 ctx=Load()),
#                             args=[
#                                 Constant(value='single_chat_prefix'),
#                                 List(
#                                     elts=[
#                                         Constant(value='')],
#                                     ctx=Load())],
#                             keywords=[]),
#                         slice=Constant(value=0),
#                         ctx=Load())),
#                 Assign(
#                     targets=[
#                         Name(id='msg', ctx=Store())],
#                     value=Call(
#                         func=Attribute(
#                             value=Call(
#                                 func=Name(id='conf', ctx=Load()),
#                                 args=[],
#                                 keywords=[]),
#                             attr='get',
#                             ctx=Load()),
#                         args=[
#                             Constant(value='subscribe_msg'),
#                             Constant(value='')],
#                         keywords=[])),
#                 Return(
#                     value=Call(
#                         func=Attribute(
#                             value=Name(id='msg', ctx=Load()),
#                             attr='format',
#                             ctx=Load()),
#                         args=[],
#                         keywords=[
#                             keyword(
#                                 arg='trigger_prefix',
#                                 value=Name(id='trigger_prefix', ctx=Load()))]))],
#             decorator_list=[]),
#         Assign(
#             targets=[
#                 Name(id='plugin_config', ctx=Store())],
#             value=Dict(keys=[], values=[])),
#         FunctionDef(
#             name='write_plugin_config',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(
#                         arg='pconf',
#                         annotation=Name(id='dict', ctx=Load()))],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Expr(
#                     value=Constant(value='\n    写入插件全局配置\n    :param pconf: 全量插件配置\n    ')),
#                 Global(
#                     names=[
#                         'plugin_config']),
#                 For(
#                     target=Name(id='k', ctx=Store()),
#                     iter=Name(id='pconf', ctx=Load()),
#                     body=[
#                         Assign(
#                             targets=[
#                                 Subscript(
#                                     value=Name(id='plugin_config', ctx=Load()),
#                                     slice=Call(
#                                         func=Attribute(
#                                             value=Name(id='k', ctx=Load()),
#                                             attr='lower',
#                                             ctx=Load()),
#                                         args=[],
#                                         keywords=[]),
#                                     ctx=Store())],
#                             value=Subscript(
#                                 value=Name(id='pconf', ctx=Load()),
#                                 slice=Name(id='k', ctx=Load()),
#                                 ctx=Load()))],
#                     orelse=[])],
#             decorator_list=[]),
#         FunctionDef(
#             name='pconf',
#             args=arguments(
#                 posonlyargs=[],
#                 args=[
#                     arg(
#                         arg='plugin_name',
#                         annotation=Name(id='str', ctx=Load()))],
#                 kwonlyargs=[],
#                 kw_defaults=[],
#                 defaults=[]),
#             body=[
#                 Expr(
#                     value=Constant(value='\n    根据插件名称获取配置\n    :param plugin_name: 插件名称\n    :return: 该插件的配置项\n    ')),
#                 Return(
#                     value=Call(
#                         func=Attribute(
#                             value=Name(id='plugin_config', ctx=Load()),
#                             attr='get',
#                             ctx=Load()),
#                         args=[
#                             Call(
#                                 func=Attribute(
#                                     value=Name(id='plugin_name', ctx=Load()),
#                                     attr='lower',
#                                     ctx=Load()),
#                                 args=[],
#                                 keywords=[])],
#                         keywords=[]))],
#             decorator_list=[],
#             returns=Name(id='dict', ctx=Load())),
#         Assign(
#             targets=[
#                 Name(id='global_config', ctx=Store())],
#             value=Dict(
#                 keys=[
#                     Constant(value='admin_users')],
#                 values=[
#                     List(elts=[], ctx=Load())]))],
#     type_ignores=[])

# %% [markdown]
# 2. 遍历 AST
#
# ast.NodeVisitor 和 ast.NodeTransformer 类可以被用来遍历和修改 AST。NodeVisitor 用于遍历树，而 NodeTransformer 允许你修改树。
#
# 例如，以下是如何使用 NodeVisitor 来打印所有的二元运算符：

# %%
class Visitor(ast.NodeVisitor):
    def visit_BinOp(self, node):
        print(f"Found a binary operation: {ast.dump(node)}")
        self.generic_visit(node)  # 继续遍历子节点

# %%
visitor = Visitor()
visitor.visit(tree)

# %%
class IncrementNumbers(ast.NodeTransformer):
    def visit_Constant(self, node):  # 在 Python 3.8+ 中，数字是使用 Constant 节点而非 Num
        if isinstance(node.value, int):  # 确保只修改整数
            return ast.Constant(value=node.value + 1)
        return node

# 解析源代码到 AST
source_code = "x = 1 + 2"
tree = ast.parse(source_code, mode='exec')

# 修改 AST
transformer = IncrementNumbers()
modified_tree = transformer.visit(tree)
ast.fix_missing_locations(modified_tree)  # 自动修复缺少的行号和列偏移

# 编译并执行修改后的 AST
exec(compile(modified_tree, filename="<ast>", mode="exec"))

# %%
# 假设 modified_tree 已经是你通过 NodeTransformer 修改过的 AST
source_code_modified = ast.unparse(modified_tree)
print(source_code_modified)
# Out:
# x = 2 + 3

# %%
import astor

# 假设 modified_tree 已经是你通过 NodeTransformer 修改过的 AST
source_code_modified = astor.to_source(modified_tree)
print(source_code_modified)
# Out:
# x = 2 + 3

# %%
from redbaron import RedBaron

# 原始代码
code = '''
def add_numbers(a, b):
    # 注释内容
    result = a + b
    return result
'''

# 翻译字典
translation_dict = {
    'add_numbers': '添加数字',
    'a': '数字一',
    'b': '数字二',
    'result': '结果'
}

# %%
# 解析代码
red = RedBaron(code)

# %%
from redbaron import RedBaron
import re

code = '''
# 这是一个计算器类
class Calculator:
    def add_numbers(self, a, b):
        # 计算两个数字的和
        result = a + b
        return result
'''

translation_dict = {
    'Calculator': '计算器',
    'add_numbers': '添加数字',
    'self': '自身',
    'a': '数字一',
    'b': '数字二',
    'result': '结果',
    'numbers': '数字',
    'calculate': '计算',
    'sum': '和'
}

red = RedBaron(code)

def translate_comment(comment_text):
    # 使用正则表达式替换注释中的标识符
    for eng, cn in translation_dict.items():
        comment_text = re.sub(r'\b' + re.escape(eng) + r'\b', cn, comment_text)
    return comment_text

def replace_names(node):
    if node.type == 'name':
        if node.value in translation_dict:
            node.value = translation_dict[node.value]
    elif node.type == 'def':
        if node.name in translation_dict:
            node.name = translation_dict[node.name]
        # 处理参数列表
        for arg_node in node.arguments:
            if arg_node.type == 'name':
                if arg_node.value in translation_dict:
                    arg_node.value = translation_dict[arg_node.value]
            elif arg_node.type == 'def_argument':
                if arg_node.target.value in translation_dict:
                    arg_node.target.value = translation_dict[arg_node.target.value]
                if arg_node.value is not None:
                    replace_names(arg_node.value)
            elif arg_node.type == 'def_parameter':
                if arg_node.name.value in translation_dict:
                    arg_node.name.value = translation_dict[arg_node.name.value]
                if arg_node.annotation is not None:
                    replace_names(arg_node.annotation)
        # 递归处理函数体
        for child in node.value:
            replace_names(child)
    elif node.type == 'class':
        if node.name in translation_dict:
            node.name = translation_dict[node.name]
        # 递归处理类体
        for child in node.value:
            replace_names(child)
    elif node.type == 'assign':
        for target in node.targets:
            replace_names(target)
        if hasattr(node, 'value'):
            replace_names(node.value)
    elif node.type == 'call':
        # 处理函数调用的参数
        for arg_node in node.arguments:
            replace_names(arg_node)
    elif node.type == 'attribute':
        # 处理属性访问
        if hasattr(node, 'value'):
            replace_names(node.value)
        if node.attr in translation_dict:
            node.attr = translation_dict[node.attr]
    elif node.type == 'comment':
        node.value = translate_comment(node.value)
    # 递归处理其他子节点
    if hasattr(node, 'value') and isinstance(node.value, list):
        for child in node.value:
            replace_names(child)
    if hasattr(node, 'else_') and node.else_ is not None:
        replace_names(node.else_)
    if hasattr(node, 'children'):
        for child in node.children:
            replace_names(child)

# 遍历语法树，替换变量名和注释内容
for node in red:
    replace_names(node)

# 生成新的代码
new_code = red.dumps()
print(new_code)
# Out:
# # 这是一个计算器类
# class 计算器:
#     def 添加数字(自身, 数字一, 数字二):
#         # 计算两个数字的和
#         result = a + b
#         return result
